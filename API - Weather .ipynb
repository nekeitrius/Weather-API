# %%
import pandas as pd #data manipulation and analysis
import numpy as np # mathematical functions
import requests # send and receive requests reponses from web servers
from bs4 import BeautifulSoup # parsing html 
import json # encode python objects into json strings and vice versa
import pprint # make text more readable
import datetime #formmatting dates and times
import time #time related functions

# %%
#Importing url of website and using BeautifulSoup for parsing.
url = requests.post('https://www.zip-codes.com/state/ne.asp')
soup = BeautifulSoup(url.content)

#Find and return all tables with id
table = soup.find_all("table", id="tblZIP")
print(table)
# Out:
# [<table border="0" cellpadding="0" cellspacing="0" class="statTable" id="tblZIP" title="All Nebraska ZIP Codes, City, County, Classification, and Area Codes." width="99%"><tr><td class="label" title="All ZIP Codes for Nebraska"><strong>ZIP Code</strong></td><td class="info" title="The official city name as designated by the USPS."><strong>City</strong></td><td class="info" title="The primary county or parish this ZIP Code serves."><strong>County</strong></td><td class="info" title="The classification type of this ZIP Code."><strong>Type</strong></td></tr><tr><td><a href="/zip-code/68001/zip-code-68001.asp" title="ZIP Code 68001">ZIP Code 68001</a></td><td><a href="/city/ne-abie.asp">Abie</a></td><td><a href="/county/ne-butler.asp">Butler</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68002/zip-code-68002.asp" title="ZIP Code 68002">ZIP Code 68002</a></td><td><a href="/city/ne-arlington.asp">Arlington</a></td><td><a href="/county/ne-washington.asp">Washington</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68003/zip-code-68003.asp" title="ZIP Code 68003">ZIP Code 68003</a></td><td><a href="/city/ne-ashland.asp">Ashland</a></td><td><a href="/county/ne-saunders.asp">Saunders</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68004/zip-code-68004.asp" title="ZIP Code 68004">ZIP Code 68004</a></td><td><a href="/city/ne-bancroft.asp">Bancroft</a></td><td><a href="/county/ne-cuming.asp">Cuming</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68005/zip-code-68005.asp" title="ZIP Code 68005">ZIP Code 68005</a></td><td><a href="/city/ne-bellevue.asp">Bellevue</a></td><td><a href="/county/ne-sarpy.asp">Sarpy</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68007/zip-code-68007.asp" title="ZIP Code 68007">ZIP Code 68007</a></td><td><a href="/city/ne-bennington.asp">Bennington</a></td><td><a href="/county/ne-douglas.asp">Douglas</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68008/zip-code-68008.asp" title="ZIP Code 68008">ZIP Code 68008</a></td><td><a href="/city/ne-blair.asp">Blair</a></td><td><a href="/county/ne-washington.asp">Washington</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68010/zip-code-68010.asp" title="ZIP Code 68010">ZIP Code 68010</a></td><td><a href="/city/ne-boys-town.asp">Boys Town</a></td><td><a href="/county/ne-douglas.asp">Douglas</a></td><td>P.O. Box</td></tr><tr><td><a href="/zip-code/68014/zip-code-68014.asp" title="ZIP Code 68014">ZIP Code 68014</a></td><td><a href="/city/ne-bruno.asp">Bruno</a></td><td><a href="/county/ne-butler.asp">Butler</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68015/zip-code-68015.asp" title="ZIP Code 68015">ZIP Code 68015</a></td><td><a href="/city/ne-cedar-bluffs.asp">Cedar Bluffs</a></td><td><a href="/county/ne-saunders.asp">Saunders</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68016/zip-code-68016.asp" title="ZIP Code 68016">ZIP Code 68016</a></td><td><a href="/city/ne-cedar-creek.asp">Cedar Creek</a></td><td><a href="/county/ne-cass.asp">Cass</a></td><td>P.O. Box</td></tr><tr><td><a href="/zip-code/68017/zip-code-68017.asp" title="ZIP Code 68017">ZIP Code 68017</a></td><td><a href="/city/ne-ceresco.asp">Ceresco</a></td><td><a href="/county/ne-saunders.asp">Saunders</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68018/zip-code-68018.asp" title="ZIP Code 68018">ZIP Code 68018</a></td><td><a href="/city/ne-colon.asp">Colon</a></td><td><a href="/county/ne-saunders.asp">Saunders</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68019/zip-code-68019.asp" title="ZIP Code 68019">ZIP Code 68019</a></td><td><a href="/city/ne-craig.asp">Craig</a></td><td><a href="/county/ne-burt.asp">Burt</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68020/zip-code-68020.asp" title="ZIP Code 68020">ZIP Code 68020</a></td><td><a href="/city/ne-decatur.asp">Decatur</a></td><td><a href="/county/ne-burt.asp">Burt</a></td><td>Standard</td></tr><tr><td><a href="/zip-code/68022/zip-code-68022.asp" title ...

# %%
#creating a empty list to hold zipcodes
zipcodes = []

#finding zipcodes
zipcode_list = table[0].find_all('a')

#extracting zipcodes
for x in zipcode_list: 
    if 'title' in x.attrs.keys():
        title = x['title']
        
        #appending zipcode list
        if title.startswith('ZIP'):
            zipcodes.append(title.split(' ')[-1])
            
#print zipcode list
print(zipcodes)
# Out:
# ['68001', '68002', '68003', '68004', '68005', '68007', '68008', '68010', '68014', '68015', '68016', '68017', '68018', '68019', '68020', '68022', '68023', '68025', '68026', '68028', '68029', '68030', '68031', '68033', '68034', '68036', '68037', '68038', '68039', '68040', '68041', '68042', '68044', '68045', '68046', '68047', '68048', '68050', '68055', '68056', '68057', '68058', '68059', '68061', '68062', '68063', '68064', '68065', '68066', '68067', '68068', '68069', '68070', '68071', '68072', '68073', '68101', '68102', '68103', '68104', '68105', '68106', '68107', '68108', '68109', '68110', '68111', '68112', '68113', '68114', '68116', '68117', '68118', '68119', '68122', '68123', '68124', '68127', '68128', '68130', '68131', '68132', '68133', '68134', '68135', '68136', '68137', '68138', '68139', '68142', '68144', '68145', '68147', '68152', '68154', '68157', '68164', '68172', '68175', '68176', '68178', '68179', '68180', '68182', '68183', '68197', '68198', '68301', '68303', '68304', '68305', '68307', '68309', '68310', '68313', '68314', '68315', '68316', '68317', '68318', '68319', '68320', '68321', '68322', '68323', '68324', '68325', '68326', '68327', '68328', '68329', '68330', '68331', '68332', '68333', '68335', '68336', '68337', '68338', '68339', '68340', '68341', '68342', '68343', '68344', '68345', '68346', '68347', '68348', '68349', '68350', '68351', '68352', '68354', '68355', '68357', '68358', '68359', '68360', '68361', '68362', '68364', '68365', '68366', '68367', '68368', '68370', '68371', '68372', '68375', '68376', '68377', '68378', '68379', '68380', '68381', '68382', '68401', '68402', '68403', '68404', '68405', '68406', '68407', '68409', '68410', '68413', '68414', '68415', '68416', '68417', '68418', '68419', '68420', '68421', '68422', '68423', '68424', '68428', '68429', '68430', '68431', '68433', '68434', '68436', '68437', '68438', '68439', '68440', '68441', '68442', '68443', '68444', '68445', '68446', '68447', '68448', '68450', '68452', '68453', '68454', '68455', '68456', '68457', '68458', '68460', '68461', '68462', '68463', '68464', '68465', '68466', '68467', '68501', '68502', '68503', '68504', '68505', '68506', '68507', '68508', '68509', '68510', '68512', '68514', '68516', '68517', '68520', '68521', '68522', '68523', '68524', '68526', '68527', '68528', '68529', '68531', '68532', '68542', '68544', '68583', '68588', '68601', '68602', '68620', '68621', '68622', '68623', '68624', '68626', '68627', '68628', '68629', '68631', '68632', '68633', '68634', '68635', '68636', '68637', '68638', '68640', '68641', '68642', '68643', '68644', '68647', '68648', '68649', '68651', '68652', '68653', '68654', '68655', '68658', '68659', '68660', '68661', '68662', '68663', '68664', '68665', '68666', '68667', '68669', '68701', '68702', '68710', '68711', '68713', '68714', '68715', '68716', '68717', '68718', '68719', '68720', '68722', '68723', '68724', '68725', '68726', '68727', '68728', '68729', '68730', '68731', '68732', '68733', '68734', '68735', '68736', '68738', '68739', '68740', '68741', '68742', '68743', '68745', '68746', '68747', '68748', '68749', '68751', '68752', '68753', '68755', '68756', '68757', '68758', '68759', '68760', '68761', '68763', '68764', '68765', '68766', '68767', '68768', '68769', '68770', '68771', '68773', '68774', '68776', '68777', '68778', '68779', '68780', '68781', '68783', '68784', '68785', '68786', '68787', '68788', '68789', '68790', '68791', '68792', '68801', '68802', '68803', '68810', '68812', '68813', '68814', '68815', '68816', '68817', '68818', '68820', '68821', '68822', '68823', '68824', '68825', '68826', '68827', '68828', '68831', '68832', '68833', '68834', '68835', '68836', '68837', '68838', '68840', '68841', '68842', '68843', '68844', '68845', '68846', '68847', '68848', '68849', '68850', '68852', '68853', '68854', '68855', '68856', '68858', '68859', '68860', '68861', '68862', '68863', '68864', '68865', '68866', '68869', '68870', '68871', '68872', '68873', '68874', '68875', '68876', '68878', '68879', '68881', '68 ...

# %% [markdown]
# Milestone 4:
# So the goal is to take zipcodes from milestone three and add them to a new function where I can pull from an api and find weather information from it.

# %%
# api key : d5d115babccbdb7ab237921a629507ab
#create weather function
def get_weather(code):
    api_key = 'd5d115babccbdb7ab237921a629507ab'
    url_base = 'http://api.openweathermap.org/data/2.5/weather?'
    url = url_base+ 'zip=' +code+ ',us&appid=' + api_key + '&units=imperial'
    r = requests.get(url)
    data = r.json()
    return data

# create zip codes list and weather data list
used_list = []
weather_data = []

# extract data from API using each zip code from list
for zc in zipcodes[:len(zipcodes)]:
    # if zip code is not in used list perform next steps and append the used zipcode list
    if zc not in used_list :
        used_list.append(zc)        
        # try to get weather data from API and append weather_data list
        try:
            data1 = get_weather(zc)
            # wait for 0.2 sec to move to another step to limit number of calls per minute 
            time.sleep(0.2)
            weather_data.append(data1)
            print(data1)
            
        # prints message to user if unable to open url
        except requests.exceptions.ConnectionError as errc:
            # handle ConnectionError exception
            print('\033[91m ' +'***Connection Failure. Please try later.***'+'\033[0m')
            break

        # handle all other exceptions
        except Exception as e:
           print('\033[91m '+"Failure to Retrieve.Please try again"+'\033[0m')
# Out:
# {'coord': {'lon': -96.9563, 'lat': 41.3479}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.35, 'feels_like': 81.01, 'temp_min': 76.23, 'temp_max': 83.1, 'pressure': 1005, 'humidity': 49, 'sea_level': 1005, 'grnd_level': 957}, 'visibility': 10000, 'wind': {'speed': 6.58, 'deg': 14, 'gust': 8.37}, 'clouds': {'all': 80}, 'dt': 1691622809, 'sys': {'type': 1, 'id': 3248, 'country': 'US', 'sunrise': 1691580642, 'sunset': 1691631366}, 'timezone': -18000, 'id': 0, 'name': 'Abie', 'cod': 200}
# {'coord': {'lon': -96.307, 'lat': 41.4417}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.43, 'feels_like': 79.43, 'temp_min': 76.75, 'temp_max': 81.37, 'pressure': 1010, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622809, 'sys': {'type': 2, 'id': 233802, 'country': 'US', 'sunrise': 1691580474, 'sunset': 1691631222}, 'timezone': -18000, 'id': 0, 'name': 'Arlington', 'cod': 200}
# {'coord': {'lon': -96.3904, 'lat': 41.0541}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.53, 'feels_like': 83.25, 'temp_min': 77.38, 'temp_max': 84.7, 'pressure': 1005, 'humidity': 66, 'sea_level': 1005, 'grnd_level': 968}, 'visibility': 10000, 'wind': {'speed': 8.68, 'deg': 28, 'gust': 10.29}, 'clouds': {'all': 82}, 'dt': 1691622809, 'sys': {'type': 2, 'id': 2039995, 'country': 'US', 'sunrise': 1691580544, 'sunset': 1691631192}, 'timezone': -18000, 'id': 0, 'name': 'Ashland', 'cod': 200}
# {'coord': {'lon': -96.6171, 'lat': 42.0267}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.24, 'feels_like': 81.64, 'temp_min': 78.37, 'temp_max': 80.67, 'pressure': 1005, 'humidity': 56, 'sea_level': 1005, 'grnd_level': 958}, 'visibility': 10000, 'wind': {'speed': 0.94, 'deg': 286, 'gust': 5.79}, 'clouds': {'all': 42}, 'dt': 1691622809, 'sys': {'type': 1, 'id': 4683, 'country': 'US', 'sunrise': 1691580471, 'sunset': 1691631374}, 'timezone': -18000, 'id': 0, 'name': 'Bancroft', 'cod': 200}
# {'coord': {'lon': -95.9099, 'lat': 41.1497}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.29, 'feels_like': 82.78, 'temp_min': 77.32, 'temp_max': 82.06, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622810, 'sys': {'type': 2, 'id': 2004418, 'country': 'US', 'sunrise': 1691580417, 'sunset': 1691631089}, 'timezone': -18000, 'id': 0, 'name': 'Bellevue', 'cod': 200}
# {'coord': {'lon': -96.1575, 'lat': 41.3623}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.31, 'feels_like': 82.8, 'temp_min': 77.49, 'temp_max': 82.09, 'pressure': 1010, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622810, 'sys': {'type': 2, 'id': 2018788, 'country': 'US', 'sunrise': 1691580448, 'sunset': 1691631176}, 'timezone': -18000, 'id': 0, 'name': 'Bennington', 'cod': 200}
# {'coord': {'lon': -96.1617, 'lat': 41.5454}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.92, 'feels_like': 79.92, 'temp_min': 77.11, 'temp_max': 81.72, 'pressure': 1011, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622810, 'sys': {'type': 2, 'id': 2003014, 'country': 'US', 'sunrise': 1691580426, 'sunset': 1691631201}, 'timezone': -18000, 'id': 0, 'name': 'Blair', 'cod': 200}
# {'coord': {'lon': -96.133, 'lat': 41.2587}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.88, 'feels_like': 79.88, 'temp_min': 76.86, 'temp_max': 81.59, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622811, 'sys': {'type': 2, 'id': 2008848, 'country': 'US', 'sunrise': 1691580456, 'sunset': 1691631157}, 'timezone': -18000, 'id': 0, 'name': 'Boys Town', 'cod': 200}
# {'coord': {'lon': -96.9646, 'lat': 41.2718}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.54, 'feels_like': 82.15, 'temp_min': 77.61, 'temp_max': 82.92, 'pressure': 1005, 'humidity': 49, 'sea_level': 1005, 'grnd_level': 953}, 'visibility': 10000, 'wind': {'speed': 6.2, 'deg': 21, 'gust': 8.03}, 'clouds': {'all': 89}, 'dt': 1691622811, 'sys': {'type': 2, 'id': 2022655, 'country': 'US', 'sunrise': 1691580654, 'sunset': 1691631358}, 'timezone': -18000, 'id': 0, 'name': 'Bruno', 'cod': 200}
# {'coord': {'lon': -96.5691, 'lat': 41.3835}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.82, 'feels_like': 78.82, 'temp_min': 77.68, 'temp_max': 80.42, 'pressure': 1010, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1691622811, 'sys': {'type': 1, 'id': 4077, 'country': 'US', 'sunrise': 1691580545, 'sunset': 1691631277}, 'timezone': -18000, 'id': 0, 'name': 'Cedar Bluffs', 'cod': 200}
# {'coord': {'lon': -96.1044, 'lat': 41.0425}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 83.21, 'temp_min': 77.67, 'temp_max': 82.4, 'pressure': 1008, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622812, 'sys': {'type': 2, 'id': 2001701, 'country': 'US', 'sunrise': 1691580477, 'sunset': 1691631122}, 'timezone': -18000, 'id': 0, 'name': 'Cedar Creek', 'cod': 200}
# {'coord': {'lon': -96.6398, 'lat': 41.0681}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.99, 'feels_like': 81.81, 'temp_min': 78.22, 'temp_max': 84.25, 'pressure': 1005, 'humidity': 43, 'sea_level': 1005, 'grnd_level': 964}, 'visibility': 10000, 'wind': {'speed': 7.07, 'deg': 30, 'gust': 10.04}, 'clouds': {'all': 83}, 'dt': 1691622812, 'sys': {'type': 1, 'id': 4736, 'country': 'US', 'sunrise': 1691580602, 'sunset': 1691631253}, 'timezone': -18000, 'id': 0, 'name': 'Ceresco', 'cod': 200}
# {'coord': {'lon': -96.6141, 'lat': 41.2883}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.34, 'feels_like': 79.34, 'temp_min': 78.08, 'temp_max': 80.82, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1691622812, 'sys': {'type': 1, 'id': 4077, 'country': 'US', 'sunrise': 1691580568, 'sunset': 1691631276}, 'timezone': -18000, 'id': 0, 'name': 'Colon', 'cod': 200}
# {'coord': {'lon': -96.3924, 'lat': 41.7715}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.29, 'feels_like': 79.29, 'temp_min': 78.42, 'temp_max': 80.08, 'pressure': 1009, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1691622813, 'sys': {'type': 1, 'id': 6059, 'country': 'US', 'sunrise': 1691580451, 'sunset': 1691631286}, 'timezone': -18000, 'id': 0, 'name': 'Craig', 'cod': 200}
# {'coord': {'lon': -96.2595, 'lat': 41.9966}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.92, 'feels_like': 79.92, 'temp_min': 78.98, 'temp_max': 80.89, 'pressure': 1005, 'humidity': 63, 'sea_level': 1005, 'grnd_level': 969}, 'visibility': 10000, 'wind': {'speed': 4.12, 'deg': 195, 'gust': 5.32}, 'clouds': {'all': 32}, 'dt': 1691622813, 'sys': {'type': 2, 'id': 2039347, 'country': 'US', 'sunrise': 1691580389, 'sunset': 1691631284}, 'timezone': -18000, 'id': 0, 'name': 'Decatur', 'cod': 200}
# {'coord': {'lon': -96.2431, 'lat': 41.2756}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.97, 'feels_like': 79.97, 'temp_min': 76.86, 'temp_max': 81.59, 'pressure': 1010, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622532, 'sys': {'type': 2, 'id': 2039709, 'country': 'US', 'sunrise': 1691580480, 'sunset': 1691631185}, 'timezone': -18000, 'id': 0, 'name': 'Elkhorn', 'cod': 200}
# {'coord': {'lon': -96.0324, 'lat': 41.4373}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.63, 'feels_like': 79.63, 'temp_min': 77.4, 'temp_max': 81.54, 'pressure': 1010, 'humidity': 63}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622813, 'sys': {'type': 1, 'id': 3506, 'country': 'US', 'sunrise': 1691580409, 'sunset': 1691631156}, 'timezone': -18000, 'id': 0, 'name': 'Fort Calhoun', 'cod': 200}
# {'coord': {'lon': -96.4945, 'lat': 41.4416}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.16, 'feels_like': 79.16, 'temp_min': 77.11, 'temp_max': 81.01, 'pressure': 1010, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1691622814, 'sys': {'type': 1, 'id': 4077, 'country': 'US', 'sunrise': 1691580519, 'sunset': 1691631267}, 'timezone': -18000, 'id': 0, 'name': 'Fremont', 'cod': 200}
# {'coord': {'lon': -96.4981, 'lat': 41.4333}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.12, 'feels_like': 79.12, 'temp_min': 77.09, 'temp_max': 81, 'pressure': 1010, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1691622814, 'sys': {'type': 1, 'id': 4077, 'country': 'US', 'sunrise': 1691580521, 'sunset': 1691631267}, 'timezone': -18000, 'id': 0, 'name': 'Fremont', 'cod': 200}
# {'coord': {'lon': -96.2458, 'lat': 41.1345}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.72, 'feels_like': 79.72, 'temp_min': 76.75, 'temp_max': 81.82, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622814, 'sys': {'type': 2, 'id': 2002782, 'country': 'US', 'sunrise': 1691580499, 'sunset': 1691631168}, 'timezone': -18000, 'id': 0, 'name': 'Gretna', 'cod': 200}
# {'coord': {'lon': -96.2869, 'lat': 41.6524}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.56, 'feels_like': 79.56, 'temp_min': 78.26, 'temp_max': 80.74, 'pressure': 1009, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1691622815, 'sys': {'type': 2, 'id': 2003014, 'country': 'US', 'sunrise': 1691580442, 'sunset': 1691631245}, 'timezone': -18000, 'id': 0, 'name': 'Herman', 'cod': 200}
# {'coord': {'lon': -96.4656, 'lat': 42.3322}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.76, 'feels_like': 81.86, 'temp_min': 79.25, 'temp_max': 82.06, 'pressure': 1009, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 270}, 'clouds': {'all': 40}, 'dt': 1691622815, 'sys': {'type': 1, 'id': 5945, 'country': 'US', 'sunrise': 1691580394, 'sunset': 1691631378}, 'timezone': -18000, 'id': 0, 'name': 'Homer', 'cod': 200}
# {'coord': {'lon': -96.5232, 'lat': 41.6414}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.23, 'feels_like': 79.23, 'temp_min': 78.78, 'temp_max': 80.94, 'pressure': 1008, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 3.83, 'deg': 312, 'gust': 8.55}, 'clouds': {'all': 45}, 'dt': 1691622815, 'sys': {'type': 2, 'id': 2008026, 'country': 'US', 'sunrise': 1691580500, 'sunset': 1691631300}, 'timezone': -18000, 'id': 0, 'name': 'Hooper', 'cod': 200}
# {'coord': {'lon': -96.5298, 'lat': 41.1748}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.23, 'feels_like': 79.23, 'temp_min': 77.18, 'temp_max': 84.38, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622815, 'sys': {'type': 1, 'id': 3248, 'country': 'US', 'sunrise': 1691580562, 'sunset': 1691631241}, 'timezone': -18000, 'id': 0, 'name': 'Ithaca', 'cod': 200}
# {'coord': {'lon': -96.1903, 'lat': 41.4526}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.08, 'feels_like': 82.36, 'temp_min': 77.31, 'temp_max': 81.91, 'pressure': 1010, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622816, 'sys': {'type': 1, 'id': 3506, 'country': 'US', 'sunrise': 1691580445, 'sunset': 1691631196}, 'timezone': -18000, 'id': 0, 'name': 'Kennard', 'cod': 200}
# {'coord': {'lon': -96.9399, 'lat': 41.4129}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.49, 'feels_like': 81.14, 'temp_min': 76.62, 'temp_max': 83.5, 'pressure': 1005, 'humidity': 49, 'sea_level': 1005, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 6.93, 'deg': 7, 'gust': 8.68}, 'clouds': {'all': 71}, 'dt': 1691622816, 'sys': {'type': 1, 'id': 5199, 'country': 'US', 'sunrise': 1691580630, 'sunset': 1691631370}, 'timezone': -18000, 'id': 0, 'name': 'Linwood', 'cod': 200}
# {'coord': {'lon': -96.1948, 'lat': 40.9967}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.37, 'feels_like': 83.28, 'temp_min': 77.34, 'temp_max': 83.8, 'pressure': 1005, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 10, 'deg': 18, 'gust': 10.36}, 'clouds': {'all': 91}, 'dt': 1691622816, 'sys': {'type': 2, 'id': 2001701, 'country': 'US', 'sunrise': 1691580505, 'sunset': 1691631138}, 'timezone': -18000, 'id': 0, 'name': 'Louisville', 'cod': 200}
# {'coord': {'lon': -96.4661, 'lat': 41.9442}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.23, 'feels_like': 79.23, 'temp_min': 78.69, 'temp_max': 80.08, 'pressure': 1005, 'humidity': 57, 'sea_level': 1005, 'grnd_level': 961}, 'visibility': 10000, 'wind': {'speed': 1.3, 'deg': 174, 'gust': 4.92}, 'clouds': {'all': 40}, 'dt': 1691622817, 'sys': {'type': 2, 'id': 2039347, 'country': 'US', 'sunrise': 1691580446, 'sunset': 1691631326}, 'timezone': -18000, 'id': 0, 'name': 'Lyons', 'cod': 200}
# {'coord': {'lon': -96.3589, 'lat': 42.1177}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.7, 'feels_like': 79.7, 'temp_min': 78.67, 'temp_max': 80.31, 'pressure': 1005, 'humidity': 53, 'sea_level': 1005, 'grnd_level': 966}, 'visibility': 10000, 'wind': {'speed': 0.78, 'deg': 359, 'gust': 6.67}, 'clouds': {'all': 42}, 'dt': 1691622817, 'sys': {'type': 2, 'id': 2039347, 'country': 'US', 'sunrise': 1691580397, 'sunset': 1691631324}, 'timezone': -18000, 'id': 0, 'name': 'Macy', 'cod': 200}
# {'coord': {'lon': -96.7327, 'lat': 41.2984}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 77.34, 'feels_like': 78.03, 'temp_min': 76.32, 'temp_max': 83.37, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622817, 'sys': {'type': 1, 'id': 3248, 'country': 'US', 'sunrise': 1691580595, 'sunset': 1691631306}, 'timezone': -18000, 'id': 0, 'name': 'Malmo', 'cod': 200}
# {'coord': {'lon': -96.4961, 'lat': 41.2393}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.07, 'feels_like': 79.07, 'temp_min': 77.02, 'temp_max': 83.37, 'pressure': 1010, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622818, 'sys': {'type': 1, 'id': 3248, 'country': 'US', 'sunrise': 1691580546, 'sunset': 1691631241}, 'timezone': -18000, 'id': 0, 'name': 'Mead', 'cod': 200}
# {'coord': {'lon': -96.4306, 'lat': 41.0946}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.2, 'feels_like': 82.78, 'temp_min': 77.25, 'temp_max': 84.56, 'pressure': 1005, 'humidity': 66, 'sea_level': 1005, 'grnd_level': 967}, 'visibility': 10000, 'wind': {'speed': 8.39, 'deg': 30, 'gust': 10.27}, 'clouds': {'all': 77}, 'dt': 1691622818, 'sys': {'type': 2, 'id': 2039995, 'country': 'US', 'sunrise': 1691580549, 'sunset': 1691631207}, 'timezone': -18000, 'id': 0, 'name': 'Memphis', 'cod': 200}
# {'coord': {'lon': -96.4441, 'lat': 41.5491}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.47, 'feels_like': 79.47, 'temp_min': 78.28, 'temp_max': 81.01, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1691622818, 'sys': {'type': 2, 'id': 2008026, 'country': 'US', 'sunrise': 1691580493, 'sunset': 1691631269}, 'timezone': -18000, 'id': 0, 'name': 'Nickerson', 'cod': 200}
# {'coord': {'lon': -96.4671, 'lat': 41.8384}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.21, 'feels_like': 79.21, 'temp_min': 78.48, 'temp_max': 80.13, 'pressure': 1005, 'humidity': 58, 'sea_level': 1005, 'grnd_level': 962}, 'visibility': 10000, 'wind': {'speed': 1.88, 'deg': 269, 'gust': 6.26}, 'clouds': {'all': 43}, 'dt': 1691622711, 'sys': {'type': 1, 'id': 6059, 'country': 'US', 'sunrise': 1691580460, 'sunset': 1691631313}, 'timezone': -18000, 'id': 0, 'name': 'Oakland', 'cod': 200}
# {'coord': {'lon': -96.0371, 'lat': 41.1523}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.67, 'feels_like': 83.32, 'temp_min': 77.65, 'temp_max': 82.38, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622819, 'sys': {'type': 2, 'id': 2085815, 'country': 'US', 'sunrise': 1691580447, 'sunset': 1691631120}, 'timezone': -18000, 'id': 0, 'name': 'Papillion', 'cod': 200}
# {'coord': {'lon': -96.7189, 'lat': 42.1177}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.92, 'feels_like': 81.9, 'temp_min': 79.75, 'temp_max': 81.23, 'pressure': 1005, 'humidity': 52, 'sea_level': 1005, 'grnd_level': 961}, 'visibility': 10000, 'wind': {'speed': 5.23, 'deg': 339, 'gust': 8.03}, 'clouds': {'all': 44}, 'dt': 1691622819, 'sys': {'type': 1, 'id': 4683, 'country': 'US', 'sunrise': 1691580484, 'sunset': 1691631410}, 'timezone': -18000, 'id': 0, 'name': 'Pender', 'cod': 200}
# {'coord': {'lon': -95.9139, 'lat': 40.9992}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.97, 'feels_like': 79.97, 'temp_min': 77.04, 'temp_max': 81.88, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 270}, 'clouds': {'all': 0}, 'dt': 1691622819, 'sys': {'type': 2, 'id': 2039125, 'country': 'US', 'sunrise': 1691580437, 'sunset': 1691631071}, 'timezone': -18000, 'id': 0, 'name': 'Plattsmouth', 'cod': 200}
# {'coord': {'lon': -96.8301, 'lat': 41.3036}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.23, 'feels_like': 76.91, 'temp_min': 76.21, 'temp_max': 83.01, 'pressure': 1005, 'humidity': 48, 'sea_level': 1005, 'grnd_level': 956}, 'visibility': 10000, 'wind': {'speed': 6.73, 'deg': 17, 'gust': 8.5}, 'clouds': {'all': 77}, 'dt': 1691622820, 'sys': {'type': 1, 'id': 3248, 'country': 'US', 'sunrise': 1691580618, 'sunset': 1691631330}, 'timezone': -18000, 'id': 0, 'name': 'Prague', 'cod': 200}
# {'coord': {'lon': -96.4929, 'lat': 42.0574}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.03, 'feels_like': 79.03, 'temp_min': 77.76, 'temp_max': 80.85, 'pressure': 1005, 'humidity': 53, 'sea_level': 1005, 'grnd_level': 957}, 'visibility': 10000, 'wind': {'speed': 0.76, 'deg': 13, 'gust': 5.48}, 'clouds': {'all': 34}, 'dt': 1691622820, 'sys': {'type': 2, 'id': 2039347, 'country': 'US', 'sunrise': 1691580437, 'sunset': 1691631348}, 'timezone': -18000, 'id': 0, 'name': 'Rosalie', 'cod': 200}
# {'coord': {'lon': -96.0905, 'lat': 41.0927}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.28, 'feels_like': 82.89, 'temp_min': 77.29, 'temp_max': 82.02, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622820, 'sys': {'type': 2, 'id': 2085815, 'country': 'US', 'sunrise': 1691580467, 'sunset': 1691631125}, 'timezone': -18000, 'id': 0, 'name': 'St Columbans', 'cod': 200}
# {'coord': {'lon': -96.6441, 'lat': 41.663}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.93, 'feels_like': 78.93, 'temp_min': 76.93, 'temp_max': 80.31, 'pressure': 1008, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 4.47, 'deg': 306, 'gust': 8.86}, 'clouds': {'all': 39}, 'dt': 1691622821, 'sys': {'type': 2, 'id': 2008026, 'country': 'US', 'sunrise': 1691580526, 'sunset': 1691631332}, 'timezone': -18000, 'id': 0, 'name': 'Scribner', 'cod': 200}
# {'coord': {'lon': -96.2462, 'lat': 41.0067}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 83.64, 'temp_min': 77.54, 'temp_max': 84.7, 'pressure': 1005, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 10.11, 'deg': 21, 'gust': 10.47}, 'clouds': {'all': 90}, 'dt': 1691622821, 'sys': {'type': 2, 'id': 2001701, 'country': 'US', 'sunrise': 1691580516, 'sunset': 1691631151}, 'timezone': -18000, 'id': 0, 'name': 'South Bend', 'cod': 200}
# {'coord': {'lon': -96.1438, 'lat': 41.0765}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.24, 'feels_like': 82.71, 'temp_min': 77.29, 'temp_max': 82.02, 'pressure': 1008, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622821, 'sys': {'type': 2, 'id': 2001701, 'country': 'US', 'sunrise': 1691580482, 'sunset': 1691631136}, 'timezone': -18000, 'id': 0, 'name': 'Springfield', 'cod': 200}
# {'coord': {'lon': -96.2281, 'lat': 41.7819}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.22, 'feels_like': 82.2, 'temp_min': 78.85, 'temp_max': 80.76, 'pressure': 1009, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 320}, 'clouds': {'all': 0}, 'dt': 1691622822, 'sys': {'type': 1, 'id': 6059, 'country': 'US', 'sunrise': 1691580410, 'sunset': 1691631248}, 'timezone': -18000, 'id': 0, 'name': 'Tekamah', 'cod': 200}
# {'coord': {'lon': -96.6904, 'lat': 42.1882}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.56, 'feels_like': 81, 'temp_min': 78.24, 'temp_max': 81.05, 'pressure': 1005, 'humidity': 47, 'sea_level': 1005, 'grnd_level': 959}, 'visibility': 10000, 'wind': {'speed': 7.96, 'deg': 349, 'gust': 8.99}, 'clouds': {'all': 39}, 'dt': 1691622822, 'sys': {'type': 1, 'id': 4683, 'country': 'US', 'sunrise': 1691580467, 'sunset': 1691631413}, 'timezone': -18000, 'id': 0, 'name': 'Thurston', 'cod': 200}
# {'coord': {'lon': -96.5037, 'lat': 41.7369}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.16, 'feels_like': 79.16, 'temp_min': 78.62, 'temp_max': 80.26, 'pressure': 1005, 'humidity': 69, 'sea_level': 1005, 'grnd_level': 963}, 'visibility': 10000, 'wind': {'speed': 3.98, 'deg': 286, 'gust': 7.74}, 'clouds': {'all': 45}, 'dt': 1691622822, 'sys': {'type': 2, 'id': 2008026, 'country': 'US', 'sunrise': 1691580483, 'sunset': 1691631308}, 'timezone': -18000, 'id': 0, 'name': 'Uehling', 'cod': 200}
# {'coord': {'lon': -96.3463, 'lat': 41.3186}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 79.97, 'feels_like': 79.97, 'temp_min': 77.29, 'temp_max': 81.9, 'pressure': 1008, 'humidity': 68}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 315, 'gust': 4}, 'clouds': {'all': 64}, 'dt': 1691622822, 'sys': {'type': 2, 'id': 233802, 'country': 'US', 'sunrise': 1691580499, 'sunset': 1691631215}, 'timezone': -18000, 'id': 0, 'name': 'Valley', 'cod': 200}
# {'coord': {'lon': -96.8091, 'lat': 41.0843}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.82, 'feels_like': 81.66, 'temp_min': 77.95, 'temp_max': 83.41, 'pressure': 1005, 'humidity': 43, 'sea_level': 1005, 'grnd_level': 956}, 'visibility': 10000, 'wind': {'speed': 5.86, 'deg': 21, 'gust': 9.71}, 'clouds': {'all': 86}, 'dt': 1691622823, 'sys': {'type': 2, 'id': 2003087, 'country': 'US', 'sunrise': 1691580641, 'sunset': 1691631296}, 'timezone': -18000, 'id': 0, 'name': 'Valparaiso', 'cod': 200}
# {'coord': {'lon': -96.6219, 'lat': 41.2117}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.28, 'feels_like': 79.05, 'temp_min': 77.05, 'temp_max': 82.02, 'pressure': 1010, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622823, 'sys': {'type': 1, 'id': 3248, 'country': 'US', 'sunrise': 1691580580, 'sunset': 1691631268}, 'timezone': -18000, 'id': 0, 'name': 'Wahoo', 'cod': 200}
# {'coord': {'lon': -96.4803, 'lat': 42.1485}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.2, 'feels_like': 80.69, 'temp_min': 78.42, 'temp_max': 81.52, 'pressure': 1005, 'humidity': 47, 'sea_level': 1005, 'grnd_level': 964}, 'visibility': 10000, 'wind': {'speed': 4.68, 'deg': 338, 'gust': 7.67}, 'clouds': {'all': 28}, 'dt': 1691622823, 'sys': {'type': 1, 'id': 5945, 'country': 'US', 'sunrise': 1691580422, 'sunset': 1691631357}, 'timezone': -18000, 'id': 0, 'name': 'Walthill', 'cod': 200}
# {'coord': {'lon': -96.2081, 'lat': 41.3975}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.15, 'feels_like': 82.58, 'temp_min': 77.32, 'temp_max': 81.93, 'pressure': 1010, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622824, 'sys': {'type': 1, 'id': 3506, 'country': 'US', 'sunrise': 1691580456, 'sunset': 1691631193}, 'timezone': -18000, 'id': 0, 'name': 'Washington', 'cod': 200}
# {'coord': {'lon': -96.3063, 'lat': 41.2702}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.13, 'feels_like': 82.67, 'temp_min': 77.23, 'temp_max': 81.97, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622824, 'sys': {'type': 2, 'id': 233802, 'country': 'US', 'sunrise': 1691580496, 'sunset': 1691631200}, 'timezone': -18000, 'id': 0, 'name': 'Waterloo', 'cod': 200}
# {'coord': {'lon': -96.7691, 'lat': 41.1811}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.14, 'feels_like': 81.28, 'temp_min': 78.46, 'temp_max': 83.91, 'pressure': 1005, 'humidity': 45, 'sea_level': 1005, 'grnd_level': 961}, 'visibility': 10000, 'wind': {'speed': 6.73, 'deg': 24, 'gust': 8.97}, 'clouds': {'all': 83}, 'dt': 1691622824, 'sys': {'type': 2, 'id': 2003087, 'country': 'US', 'sunrise': 1691580619, 'sunset': 1691631299}, 'timezone': -18000, 'id': 0, 'name': 'Weston', 'cod': 200}
# {'coord': {'lon': -96.4685, 'lat': 42.2339}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.28, 'feels_like': 82.26, 'temp_min': 78.4, 'temp_max': 81.5, 'pressure': 1009, 'humidity': 61}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 270}, 'clouds': {'all': 40}, 'dt': 1691622825, 'sys': {'type': 1, 'id': 5945, 'country': 'US', 'sunrise': 1691580408, 'sunset': 1691631366}, 'timezone': -18000, 'id': 0, 'name': 'Winnebago', 'cod': 200}
# {'coord': {'lon': -96.5033, 'lat': 41.6102}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.2, 'feels_like': 79.2, 'temp_min': 78.78, 'temp_max': 80.94, 'pressure': 1009, 'humidity': 69}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 40}, 'dt': 1691622825, 'sys': {'type': 2, 'id': 2008026, 'country': 'US', 'sunrise': 1691580499, 'sunset': 1691631291}, 'timezone': -18000, 'id': 0, 'name': 'Winslow', 'cod': 200}
# {'coord': {'lon': -96.3932, 'lat': 41.234}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 80.17, 'feels_like': 82.98, 'temp_min': 78.42, 'temp_max': 81.88, 'pressure': 1005, 'humidity': 68, 'sea_level': 1005, 'grnd_level': 966}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 30, 'gust': 9.98}, 'clouds': {'all': 67}, 'dt': 1691622825, 'sys': {'type': 2, 'id': 233802, 'country': 'US', 'sunrise': 1691580522, 'sunset': 1691631216}, 'timezone': -18000, 'id': 0, 'name': 'Yutan', 'cod': 200}
# {'coord': {'lon': -95.9378, 'lat': 41.2586}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.51, 'feels_like': 82.96, 'temp_min': 78.06, 'temp_max': 82.2, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622628, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580409, 'sunset': 1691631110}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9409, 'lat': 41.259}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.2, 'feels_like': 82.53, 'temp_min': 77.9, 'temp_max': 82.04, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622826, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580410, 'sunset': 1691631111}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9378, 'lat': 41.2586}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.51, 'feels_like': 82.96, 'temp_min': 78.06, 'temp_max': 82.2, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622680, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580409, 'sunset': 1691631110}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9999, 'lat': 41.2919}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.88, 'feels_like': 79.88, 'temp_min': 76.98, 'temp_max': 81.72, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622826, 'sys': {'type': 2, 'id': 2079634, 'country': 'US', 'sunrise': 1691580420, 'sunset': 1691631129}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9629, 'lat': 41.2435}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 79.84, 'feels_like': 79.84, 'temp_min': 77.5, 'temp_max': 81.64, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622827, 'sys': {'type': 2, 'id': 2079634, 'country': 'US', 'sunrise': 1691580417, 'sunset': 1691631114}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.998, 'lat': 41.2403}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.28, 'feels_like': 82.76, 'temp_min': 77.34, 'temp_max': 82.09, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622827, 'sys': {'type': 2, 'id': 2079634, 'country': 'US', 'sunrise': 1691580426, 'sunset': 1691631122}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9559, 'lat': 41.2068}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.44, 'feels_like': 82.98, 'temp_min': 77.88, 'temp_max': 82.02, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622552, 'sys': {'type': 2, 'id': 38540, 'country': 'US', 'sunrise': 1691580420, 'sunset': 1691631107}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9336, 'lat': 41.2382}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.13, 'feels_like': 82.44, 'temp_min': 77.68, 'temp_max': 81.82, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622689, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580411, 'sunset': 1691631106}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9378, 'lat': 41.2586}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.42, 'feels_like': 82.83, 'temp_min': 78.06, 'temp_max': 82.2, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622790, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580409, 'sunset': 1691631110}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9361, 'lat': 41.2933}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.35, 'feels_like': 82.72, 'temp_min': 77.52, 'temp_max': 82.26, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622828, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580404, 'sunset': 1691631114}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.965, 'lat': 41.2962}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.22, 'feels_like': 82.67, 'temp_min': 77.34, 'temp_max': 82.09, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622828, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580411, 'sunset': 1691631121}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9597, 'lat': 41.3296}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.35, 'feels_like': 82.85, 'temp_min': 77.52, 'temp_max': 82.26, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622829, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580405, 'sunset': 1691631124}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9404, 'lat': 41.2563}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.2, 'feels_like': 82.53, 'temp_min': 77.9, 'temp_max': 82.04, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622829, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580410, 'sunset': 1691631110}, 'timezone': -18000, 'id': 0, 'name': 'Offutt Afb', 'cod': 200}
# {'coord': {'lon': -96.0493, 'lat': 41.2656}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.11, 'feels_like': 82.53, 'temp_min': 77.16, 'temp_max': 81.9, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622829, 'sys': {'type': 2, 'id': 2044496, 'country': 'US', 'sunrise': 1691580435, 'sunset': 1691631137}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.1495, 'lat': 41.2879}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.83, 'feels_like': 79.83, 'temp_min': 76.84, 'temp_max': 81.57, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622830, 'sys': {'type': 2, 'id': 2039709, 'country': 'US', 'sunrise': 1691580456, 'sunset': 1691631164}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9953, 'lat': 41.2064}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.17, 'feels_like': 82.6, 'temp_min': 77.76, 'temp_max': 81.9, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622830, 'sys': {'type': 2, 'id': 38540, 'country': 'US', 'sunrise': 1691580430, 'sunset': 1691631117}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.1661, 'lat': 41.2606}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.1, 'feels_like': 82.49, 'temp_min': 77.05, 'temp_max': 81.79, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622830, 'sys': {'type': 2, 'id': 2008848, 'country': 'US', 'sunrise': 1691580464, 'sunset': 1691631165}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9378, 'lat': 41.2586}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.42, 'feels_like': 82.83, 'temp_min': 78.06, 'temp_max': 82.2, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622790, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580409, 'sunset': 1691631110}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.0458, 'lat': 41.3333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.01, 'feels_like': 82.38, 'temp_min': 77.09, 'temp_max': 81.82, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622831, 'sys': {'type': 2, 'id': 2018788, 'country': 'US', 'sunrise': 1691580425, 'sunset': 1691631145}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9393, 'lat': 41.1156}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.94, 'feels_like': 83.73, 'temp_min': 78.35, 'temp_max': 82.49, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 40}, 'dt': 1691622737, 'sys': {'type': 2, 'id': 2022710, 'country': 'US', 'sunrise': 1691580428, 'sunset': 1691631092}, 'timezone': -18000, 'id': 0, 'name': 'Bellevue', 'cod': 200}
# {'coord': {'lon': -96.0495, 'lat': 41.2338}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.58, 'feels_like': 83.19, 'temp_min': 77.61, 'temp_max': 82.35, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622832, 'sys': {'type': 2, 'id': 2033981, 'country': 'US', 'sunrise': 1691580439, 'sunset': 1691631133}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.0612, 'lat': 41.2074}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.64, 'feels_like': 83.26, 'temp_min': 77.23, 'temp_max': 83.7, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622447, 'sys': {'type': 2, 'id': 2001610, 'country': 'US', 'sunrise': 1691580445, 'sunset': 1691631133}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.0658, 'lat': 41.1814}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.26, 'feels_like': 82.72, 'temp_min': 77.25, 'temp_max': 81.99, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622832, 'sys': {'type': 2, 'id': 2001610, 'country': 'US', 'sunrise': 1691580450, 'sunset': 1691631130}, 'timezone': -18000, 'id': 0, 'name': 'La Vista', 'cod': 200}
# {'coord': {'lon': -96.1688, 'lat': 41.2355}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.22, 'feels_like': 82.67, 'temp_min': 77.07, 'temp_max': 81.81, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622612, 'sys': {'type': 2, 'id': 2008848, 'country': 'US', 'sunrise': 1691580468, 'sunset': 1691631162}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9639, 'lat': 41.2647}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.11, 'feels_like': 82.4, 'temp_min': 77.81, 'temp_max': 81.95, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622833, 'sys': {'type': 2, 'id': 2079634, 'country': 'US', 'sunrise': 1691580415, 'sunset': 1691631117}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.996, 'lat': 41.2657}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.02, 'feels_like': 82.29, 'temp_min': 77.68, 'temp_max': 81.82, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622833, 'sys': {'type': 2, 'id': 2079634, 'country': 'US', 'sunrise': 1691580422, 'sunset': 1691631125}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.0131, 'lat': 41.1416}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.49, 'feels_like': 83.07, 'temp_min': 77.49, 'temp_max': 82.22, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 40}, 'dt': 1691622833, 'sys': {'type': 2, 'id': 2085815, 'country': 'US', 'sunrise': 1691580442, 'sunset': 1691631113}, 'timezone': -18000, 'id': 0, 'name': 'Papillion', 'cod': 200}
# {'coord': {'lon': -96.0546, 'lat': 41.2949}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.26, 'feels_like': 82.72, 'temp_min': 77.32, 'temp_max': 82.06, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 0}, 'dt': 1691622834, 'sys': {'type': 2, 'id': 2044496, 'country': 'US', 'sunrise': 1691580432, 'sunset': 1691631142}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.1698, 'lat': 41.2104}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.97, 'feels_like': 79.97, 'temp_min': 76.95, 'temp_max': 81.68, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622834, 'sys': {'type': 2, 'id': 2002782, 'country': 'US', 'sunrise': 1691580471, 'sunset': 1691631159}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.2096, 'lat': 41.1683}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.26, 'feels_like': 82.85, 'temp_min': 76.91, 'temp_max': 83.39, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622462, 'sys': {'type': 2, 'id': 2002782, 'country': 'US', 'sunrise': 1691580486, 'sunset': 1691631163}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.1147, 'lat': 41.2075}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.67, 'feels_like': 83.32, 'temp_min': 77.27, 'temp_max': 83.73, 'pressure': 1009, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622462, 'sys': {'type': 1, 'id': 4920, 'country': 'US', 'sunrise': 1691580458, 'sunset': 1691631146}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -96.1376, 'lat': 41.1549}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.19, 'feels_like': 82.74, 'temp_min': 77.16, 'temp_max': 81.9, 'pressure': 1009, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 300}, 'clouds': {'all': 0}, 'dt': 1691622835, 'sys': {'type': 2, 'id': 2002782, 'country': 'US', 'sunrise': 1691580471, 'sunset': 1691631144}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# {'coord': {'lon': -95.9378, 'lat': 41.2586}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.51, 'feels_like': 82.96, 'temp_min': 78.06, 'temp_max': 82.2, 'pressure': 1009, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 10}, 'clouds': {'all': 40}, 'dt': 1691622680, 'sys': {'type': 2, 'id': 2003015, 'country': 'US', 'sunrise': 1691580409, 'sunset': 1691631110}, 'timezone': -18000, 'id': 0, 'name': 'Omaha', 'cod': 200}
# ...
# {'coord': {'lon': -101.9636, 'lat': 41.9776}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.68, 'feels_like': 75.83, 'temp_min': 76.68, 'temp_max': 76.68, 'pressure': 1008, 'humidity': 38, 'sea_level': 1008, 'grnd_level': 882}, 'visibility': 10000, 'wind': {'speed': 3.8, 'deg': 31, 'gust': 5.95}, 'clouds': {'all': 86}, 'dt': 1691623033, 'sys': {'country': 'US', 'sunrise': 1691581762, 'sunset': 1691632649}, 'timezone': -21600, 'id': 0, 'name': 'Ashby', 'cod': 200}
# {'coord': {'lon': -103.3019, 'lat': 41.7579}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.66, 'feels_like': 82.4, 'temp_min': 81.77, 'temp_max': 85.48, 'pressure': 1007, 'humidity': 36, 'sea_level': 1007, 'grnd_level': 884}, 'visibility': 10000, 'wind': {'speed': 6.71, 'deg': 340, 'gust': 9.22}, 'clouds': {'all': 1}, 'dt': 1691623033, 'sys': {'type': 2, 'id': 2005065, 'country': 'US', 'sunrise': 1691582112, 'sunset': 1691632941}, 'timezone': -21600, 'id': 0, 'name': 'Bayard', 'cod': 200}
# {'coord': {'lon': -102.0885, 'lat': 42.0211}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.36, 'feels_like': 76.5, 'temp_min': 77.36, 'temp_max': 77.36, 'pressure': 1008, 'humidity': 36, 'sea_level': 1008, 'grnd_level': 881}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 14, 'gust': 6.4}, 'clouds': {'all': 74}, 'dt': 1691623033, 'sys': {'country': 'US', 'sunrise': 1691581786, 'sunset': 1691632685}, 'timezone': -21600, 'id': 0, 'name': 'Bingham', 'cod': 200}
# {'coord': {'lon': -103.0701, 'lat': 41.6766}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.75, 'feels_like': 82.49, 'temp_min': 81.18, 'temp_max': 83.77, 'pressure': 1012, 'humidity': 36}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 284, 'gust': 7}, 'clouds': {'all': 5}, 'dt': 1691623034, 'sys': {'type': 2, 'id': 2005065, 'country': 'US', 'sunrise': 1691582068, 'sunset': 1691632875}, 'timezone': -21600, 'id': 0, 'name': 'Bridgeport', 'cod': 200}
# {'coord': {'lon': -102.9953, 'lat': 42.8193}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81, 'feels_like': 80.65, 'temp_min': 80.17, 'temp_max': 81.88, 'pressure': 1013, 'humidity': 40}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1691623034, 'sys': {'type': 2, 'id': 2007979, 'country': 'US', 'sunrise': 1691581896, 'sunset': 1691633010}, 'timezone': -21600, 'id': 0, 'name': 'Chadron', 'cod': 200}
# {'coord': {'lon': -103.4053, 'lat': 42.6758}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.42, 'feels_like': 79.18, 'temp_min': 79.45, 'temp_max': 81.9, 'pressure': 1007, 'humidity': 26, 'sea_level': 1007, 'grnd_level': 885}, 'visibility': 10000, 'wind': {'speed': 2.77, 'deg': 344, 'gust': 7.94}, 'clouds': {'all': 1}, 'dt': 1691623034, 'sys': {'type': 1, 'id': 3593, 'country': 'US', 'sunrise': 1691582014, 'sunset': 1691633089}, 'timezone': -21600, 'id': 0, 'name': 'Crawford', 'cod': 200}
# {'coord': {'lon': -102.2807, 'lat': 42.0586}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 80.62, 'feels_like': 79.79, 'temp_min': 80.62, 'temp_max': 80.62, 'pressure': 1008, 'humidity': 33, 'sea_level': 1008, 'grnd_level': 881}, 'visibility': 10000, 'wind': {'speed': 5.12, 'deg': 342, 'gust': 7.47}, 'clouds': {'all': 44}, 'dt': 1691623035, 'sys': {'type': 1, 'id': 3249, 'country': 'US', 'sunrise': 1691581827, 'sunset': 1691632736}, 'timezone': -21600, 'id': 0, 'name': 'Ellsworth', 'cod': 200}
# {'coord': {'lon': -103.6629, 'lat': 41.822}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.61, 'feels_like': 82.24, 'temp_min': 81.45, 'temp_max': 85.17, 'pressure': 1009, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 279, 'gust': 7}, 'clouds': {'all': 0}, 'dt': 1691623035, 'sys': {'type': 2, 'id': 2039237, 'country': 'US', 'sunrise': 1691582191, 'sunset': 1691633036}, 'timezone': -21600, 'id': 0, 'name': 'Gering', 'cod': 200}
# {'coord': {'lon': -102.2049, 'lat': 42.8068}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 78.76, 'feels_like': 78.76, 'temp_min': 78.76, 'temp_max': 79.74, 'pressure': 1013, 'humidity': 44}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 260}, 'clouds': {'all': 40}, 'dt': 1691623035, 'sys': {'type': 1, 'id': 4265, 'country': 'US', 'sunrise': 1691581708, 'sunset': 1691632819}, 'timezone': -21600, 'id': 0, 'name': 'Gordon', 'cod': 200}
# {'coord': {'lon': -103.7111, 'lat': 41.5531}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.44, 'feels_like': 80.06, 'temp_min': 78.12, 'temp_max': 82.74, 'pressure': 1008, 'humidity': 38, 'sea_level': 1008, 'grnd_level': 861}, 'visibility': 10000, 'wind': {'speed': 6.78, 'deg': 344, 'gust': 10.27}, 'clouds': {'all': 0}, 'dt': 1691623036, 'sys': {'type': 2, 'id': 2011467, 'country': 'US', 'sunrise': 1691582238, 'sunset': 1691633012}, 'timezone': -21600, 'id': 0, 'name': 'Harrisburg', 'cod': 200}
# {'coord': {'lon': -103.8827, 'lat': 42.6872}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.01, 'feels_like': 77.43, 'temp_min': 77.18, 'temp_max': 78.01, 'pressure': 1014, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 53, 'gust': 5.99}, 'clouds': {'all': 3}, 'dt': 1691623036, 'sys': {'type': 2, 'id': 2005961, 'country': 'US', 'sunrise': 1691582127, 'sunset': 1691633205}, 'timezone': -21600, 'id': 0, 'name': 'Harrison', 'cod': 200}
# {'coord': {'lon': -102.6756, 'lat': 42.6401}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 79.57, 'feels_like': 79.57, 'temp_min': 77.99, 'temp_max': 80.69, 'pressure': 1008, 'humidity': 32, 'sea_level': 1008, 'grnd_level': 885}, 'visibility': 10000, 'wind': {'speed': 5.28, 'deg': 317, 'gust': 6.35}, 'clouds': {'all': 11}, 'dt': 1691622808, 'sys': {'type': 2, 'id': 2007979, 'country': 'US', 'sunrise': 1691581844, 'sunset': 1691632909}, 'timezone': -21600, 'id': 0, 'name': 'Hay Springs', 'cod': 200}
# {'coord': {'lon': -103.0644, 'lat': 42.3312}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 79.23, 'feels_like': 79.23, 'temp_min': 79.23, 'temp_max': 79.45, 'pressure': 1008, 'humidity': 30, 'sea_level': 1008, 'grnd_level': 871}, 'visibility': 10000, 'wind': {'speed': 5.03, 'deg': 339, 'gust': 8.01}, 'clouds': {'all': 2}, 'dt': 1691623037, 'sys': {'type': 2, 'id': 2020636, 'country': 'US', 'sunrise': 1691581979, 'sunset': 1691632960}, 'timezone': -21600, 'id': 0, 'name': 'Hemingford', 'cod': 200}
# {'coord': {'lon': -101.7483, 'lat': 42.007}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 76.41, 'feels_like': 75.67, 'temp_min': 76.41, 'temp_max': 76.41, 'pressure': 1008, 'humidity': 41, 'sea_level': 1008, 'grnd_level': 886}, 'visibility': 10000, 'wind': {'speed': 2.42, 'deg': 353, 'gust': 5.37}, 'clouds': {'all': 81}, 'dt': 1691623037, 'sys': {'country': 'US', 'sunrise': 1691581706, 'sunset': 1691632601}, 'timezone': -21600, 'id': 0, 'name': 'Hyannis', 'cod': 200}
# {'coord': {'lon': -102.4437, 'lat': 42.0496}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 80.71, 'feels_like': 79.77, 'temp_min': 80.49, 'temp_max': 80.71, 'pressure': 1007, 'humidity': 32, 'sea_level': 1007, 'grnd_level': 882}, 'visibility': 10000, 'wind': {'speed': 5.57, 'deg': 344, 'gust': 7.61}, 'clouds': {'all': 18}, 'dt': 1691623037, 'sys': {'type': 1, 'id': 3249, 'country': 'US', 'sunrise': 1691581868, 'sunset': 1691632774}, 'timezone': -21600, 'id': 0, 'name': 'Lakeside', 'cod': 200}
# {'coord': {'lon': -104.0066, 'lat': 41.8918}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.91, 'feels_like': 81.16, 'temp_min': 80.92, 'temp_max': 84.65, 'pressure': 1007, 'humidity': 38, 'sea_level': 1007, 'grnd_level': 877}, 'visibility': 10000, 'wind': {'speed': 3.38, 'deg': 350, 'gust': 8.14}, 'clouds': {'all': 1}, 'dt': 1691623038, 'sys': {'type': 2, 'id': 2043916, 'country': 'US', 'sunrise': 1691582264, 'sunset': 1691633128}, 'timezone': -21600, 'id': 0, 'name': 'Lyman', 'cod': 200}
# {'coord': {'lon': -103.4164, 'lat': 41.7469}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 84.06, 'feels_like': 81.77, 'temp_min': 81.93, 'temp_max': 85.64, 'pressure': 1007, 'humidity': 27, 'sea_level': 1007, 'grnd_level': 885}, 'visibility': 10000, 'wind': {'speed': 5.73, 'deg': 337, 'gust': 8.81}, 'clouds': {'all': 1}, 'dt': 1691623038, 'sys': {'type': 1, 'id': 3415, 'country': 'US', 'sunrise': 1691582141, 'sunset': 1691632967}, 'timezone': -21600, 'id': 0, 'name': 'Mcgrew', 'cod': 200}
# {'coord': {'lon': -103.2564, 'lat': 42.5244}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 78.19, 'feels_like': 77.02, 'temp_min': 77.65, 'temp_max': 79.11, 'pressure': 1008, 'humidity': 28, 'sea_level': 1008, 'grnd_level': 870}, 'visibility': 10000, 'wind': {'speed': 3.2, 'deg': 347, 'gust': 8.19}, 'clouds': {'all': 1}, 'dt': 1691623038, 'sys': {'type': 1, 'id': 3593, 'country': 'US', 'sunrise': 1691581999, 'sunset': 1691633032}, 'timezone': -21600, 'id': 0, 'name': 'Marsland', 'cod': 200}
# {'coord': {'lon': -103.5177, 'lat': 41.7816}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 84.02, 'feels_like': 82.47, 'temp_min': 81.79, 'temp_max': 85.51, 'pressure': 1014, 'humidity': 34}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1691623039, 'sys': {'type': 1, 'id': 3415, 'country': 'US', 'sunrise': 1691582161, 'sunset': 1691632996}, 'timezone': -21600, 'id': 0, 'name': 'Melbeta', 'cod': 200}
# {'coord': {'lon': -103.489, 'lat': 41.8493}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.37, 'feels_like': 81.81, 'temp_min': 81.37, 'temp_max': 85.1, 'pressure': 1014, 'humidity': 33}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1691623039, 'sys': {'type': 1, 'id': 3415, 'country': 'US', 'sunrise': 1691582145, 'sunset': 1691632998}, 'timezone': -21600, 'id': 0, 'name': 'Minatare', 'cod': 200}
# {'coord': {'lon': -103.796, 'lat': 41.9459}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.99, 'feels_like': 80.92, 'temp_min': 81.12, 'temp_max': 84.85, 'pressure': 1014, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 248, 'gust': 4}, 'clouds': {'all': 0}, 'dt': 1691623039, 'sys': {'type': 2, 'id': 2043916, 'country': 'US', 'sunrise': 1691582206, 'sunset': 1691633084}, 'timezone': -21600, 'id': 0, 'name': 'Mitchell', 'cod': 200}
# {'coord': {'lon': -103.9182, 'lat': 41.9681}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.9, 'feels_like': 81.14, 'temp_min': 81.19, 'temp_max': 84.9, 'pressure': 1007, 'humidity': 38, 'sea_level': 1007, 'grnd_level': 879}, 'visibility': 10000, 'wind': {'speed': 3.2, 'deg': 324, 'gust': 8.01}, 'clouds': {'all': 1}, 'dt': 1691623040, 'sys': {'type': 2, 'id': 2043916, 'country': 'US', 'sunrise': 1691582233, 'sunset': 1691633116}, 'timezone': -21600, 'id': 0, 'name': 'Morrill', 'cod': 200}
# {'coord': {'lon': -102.4657, 'lat': 42.7379}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 78.4, 'feels_like': 77.5, 'temp_min': 78.1, 'temp_max': 79.57, 'pressure': 1008, 'humidity': 33, 'sea_level': 1008, 'grnd_level': 886}, 'visibility': 10000, 'wind': {'speed': 5.68, 'deg': 309, 'gust': 6.33}, 'clouds': {'all': 22}, 'dt': 1691623040, 'sys': {'type': 1, 'id': 4265, 'country': 'US', 'sunrise': 1691581780, 'sunset': 1691632872}, 'timezone': -21600, 'id': 0, 'name': 'Rushville', 'cod': 200}
# {'coord': {'lon': -103.6619, 'lat': 41.872}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.48, 'feels_like': 82.13, 'temp_min': 81.55, 'temp_max': 85.28, 'pressure': 1010, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 279, 'gust': 7}, 'clouds': {'all': 0}, 'dt': 1691623040, 'sys': {'type': 1, 'id': 3415, 'country': 'US', 'sunrise': 1691582184, 'sunset': 1691633042}, 'timezone': -21600, 'id': 0, 'name': 'Scottsbluff', 'cod': 200}
# {'coord': {'lon': -103.6672, 'lat': 41.8666}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 83.93, 'feels_like': 82.4, 'temp_min': 81.55, 'temp_max': 85.28, 'pressure': 1008, 'humidity': 34}, 'visibility': 10000, 'wind': {'speed': 0, 'deg': 0}, 'clouds': {'all': 0}, 'dt': 1691622907, 'sys': {'type': 2, 'id': 2080409, 'country': 'US', 'sunrise': 1691582186, 'sunset': 1691633043}, 'timezone': -21600, 'id': 0, 'name': 'Scottsbluff', 'cod': 200}
# {'coord': {'lon': -102.5546, 'lat': 42.9969}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 80.64, 'feels_like': 80.47, 'temp_min': 79.68, 'temp_max': 82.38, 'pressure': 1013, 'humidity': 41}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 260}, 'clouds': {'all': 0}, 'dt': 1691623041, 'sys': {'type': 1, 'id': 4501, 'country': 'US', 'sunrise': 1691581766, 'sunset': 1691632929}, 'timezone': -21600, 'id': 0, 'name': 'Whiteclay', 'cod': 200}
# {'coord': {'lon': -101.5216, 'lat': 41.9584}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.74, 'feels_like': 75.18, 'temp_min': 75.74, 'temp_max': 75.74, 'pressure': 1008, 'humidity': 46, 'sea_level': 1008, 'grnd_level': 888}, 'visibility': 10000, 'wind': {'speed': 4.76, 'deg': 283, 'gust': 6.78}, 'clouds': {'all': 73}, 'dt': 1691623041, 'sys': {'country': 'US', 'sunrise': 1691581658, 'sunset': 1691632541}, 'timezone': -21600, 'id': 0, 'name': 'Whitman', 'cod': 200}
# {'coord': {'lon': -103.2396, 'lat': 42.7559}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.66, 'feels_like': 81.07, 'temp_min': 80.44, 'temp_max': 81.66, 'pressure': 1013, 'humidity': 39}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 220}, 'clouds': {'all': 0}, 'dt': 1691623041, 'sys': {'type': 1, 'id': 3593, 'country': 'US', 'sunrise': 1691581964, 'sunset': 1691633060}, 'timezone': -21600, 'id': 0, 'name': 'Whitney', 'cod': 200}

# %%
# create 'weather.json' file with weather data
with open('weather.json', 'w') as outfile:
    json.dump(weather_data, outfile)

# %%
# read json file
with open('weather.json', 'r') as myfile:
    data = myfile.read()

    # parse file
    weather_data1 = json.loads(data)
    
    # using pprint to print each record
    # output will be a dictonary for each record
    for item in weather_data1:
        pprint.pprint(item)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 80},
#  'cod': 200,
#  'coord': {'lat': 41.3479, 'lon': -96.9563},
#  'dt': 1691622809,
#  'id': 0,
#  'main': {'feels_like': 81.01,
#           'grnd_level': 957,
#           'humidity': 49,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.35,
#           'temp_max': 83.1,
#           'temp_min': 76.23},
#  'name': 'Abie',
#  'sys': {'country': 'US',
#          'id': 3248,
#          'sunrise': 1691580642,
#          'sunset': 1691631366,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 14, 'gust': 8.37, 'speed': 6.58}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.4417, 'lon': -96.307},
#  'dt': 1691622809,
#  'id': 0,
#  'main': {'feels_like': 79.43,
#           'humidity': 65,
#           'pressure': 1010,
#           'temp': 79.43,
#           'temp_max': 81.37,
#           'temp_min': 76.75},
#  'name': 'Arlington',
#  'sys': {'country': 'US',
#          'id': 233802,
#          'sunrise': 1691580474,
#          'sunset': 1691631222,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 82},
#  'cod': 200,
#  'coord': {'lat': 41.0541, 'lon': -96.3904},
#  'dt': 1691622809,
#  'id': 0,
#  'main': {'feels_like': 83.25,
#           'grnd_level': 968,
#           'humidity': 66,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.53,
#           'temp_max': 84.7,
#           'temp_min': 77.38},
#  'name': 'Ashland',
#  'sys': {'country': 'US',
#          'id': 2039995,
#          'sunrise': 1691580544,
#          'sunset': 1691631192,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 28, 'gust': 10.29, 'speed': 8.68}}
# {'base': 'stations',
#  'clouds': {'all': 42},
#  'cod': 200,
#  'coord': {'lat': 42.0267, 'lon': -96.6171},
#  'dt': 1691622809,
#  'id': 0,
#  'main': {'feels_like': 81.64,
#           'grnd_level': 958,
#           'humidity': 56,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.24,
#           'temp_max': 80.67,
#           'temp_min': 78.37},
#  'name': 'Bancroft',
#  'sys': {'country': 'US',
#          'id': 4683,
#          'sunrise': 1691580471,
#          'sunset': 1691631374,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 286, 'gust': 5.79, 'speed': 0.94}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.1497, 'lon': -95.9099},
#  'dt': 1691622810,
#  'id': 0,
#  'main': {'feels_like': 82.78,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.29,
#           'temp_max': 82.06,
#           'temp_min': 77.32},
#  'name': 'Bellevue',
#  'sys': {'country': 'US',
#          'id': 2004418,
#          'sunrise': 1691580417,
#          'sunset': 1691631089,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.3623, 'lon': -96.1575},
#  'dt': 1691622810,
#  'id': 0,
#  'main': {'feels_like': 82.8,
#           'humidity': 65,
#           'pressure': 1010,
#           'temp': 80.31,
#           'temp_max': 82.09,
#           'temp_min': 77.49},
#  'name': 'Bennington',
#  'sys': {'country': 'US',
#          'id': 2018788,
#          'sunrise': 1691580448,
#          'sunset': 1691631176,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.5454, 'lon': -96.1617},
#  'dt': 1691622810,
#  'id': 0,
#  'main': {'feels_like': 79.92,
#           'humidity': 61,
#           'pressure': 1011,
#           'temp': 79.92,
#           'temp_max': 81.72,
#           'temp_min': 77.11},
#  'name': 'Blair',
#  'sys': {'country': 'US',
#          'id': 2003014,
#          'sunrise': 1691580426,
#          'sunset': 1691631201,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2587, 'lon': -96.133},
#  'dt': 1691622811,
#  'id': 0,
#  'main': {'feels_like': 79.88,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 79.88,
#           'temp_max': 81.59,
#           'temp_min': 76.86},
#  'name': 'Boys Town',
#  'sys': {'country': 'US',
#          'id': 2008848,
#          'sunrise': 1691580456,
#          'sunset': 1691631157,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 89},
#  'cod': 200,
#  'coord': {'lat': 41.2718, 'lon': -96.9646},
#  'dt': 1691622811,
#  'id': 0,
#  'main': {'feels_like': 82.15,
#           'grnd_level': 953,
#           'humidity': 49,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 81.54,
#           'temp_max': 82.92,
#           'temp_min': 77.61},
#  'name': 'Bruno',
#  'sys': {'country': 'US',
#          'id': 2022655,
#          'sunrise': 1691580654,
#          'sunset': 1691631358,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 21, 'gust': 8.03, 'speed': 6.2}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.3835, 'lon': -96.5691},
#  'dt': 1691622811,
#  'id': 0,
#  'main': {'feels_like': 78.82,
#           'humidity': 68,
#           'pressure': 1010,
#           'temp': 78.82,
#           'temp_max': 80.42,
#           'temp_min': 77.68},
#  'name': 'Cedar Bluffs',
#  'sys': {'country': 'US',
#          'id': 4077,
#          'sunrise': 1691580545,
#          'sunset': 1691631277,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.0425, 'lon': -96.1044},
#  'dt': 1691622812,
#  'id': 0,
#  'main': {'feels_like': 83.21,
#           'humidity': 65,
#           'pressure': 1008,
#           'temp': 80.6,
#           'temp_max': 82.4,
#           'temp_min': 77.67},
#  'name': 'Cedar Creek',
#  'sys': {'country': 'US',
#          'id': 2001701,
#          'sunrise': 1691580477,
#          'sunset': 1691631122,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 41.0681, 'lon': -96.6398},
#  'dt': 1691622812,
#  'id': 0,
#  'main': {'feels_like': 81.81,
#           'grnd_level': 964,
#           'humidity': 43,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 81.99,
#           'temp_max': 84.25,
#           'temp_min': 78.22},
#  'name': 'Ceresco',
#  'sys': {'country': 'US',
#          'id': 4736,
#          'sunrise': 1691580602,
#          'sunset': 1691631253,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'gust': 10.04, 'speed': 7.07}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2883, 'lon': -96.6141},
#  'dt': 1691622812,
#  'id': 0,
#  'main': {'feels_like': 79.34,
#           'humidity': 69,
#           'pressure': 1010,
#           'temp': 79.34,
#           'temp_max': 80.82,
#           'temp_min': 78.08},
#  'name': 'Colon',
#  'sys': {'country': 'US',
#          'id': 4077,
#          'sunrise': 1691580568,
#          'sunset': 1691631276,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.7715, 'lon': -96.3924},
#  'dt': 1691622813,
#  'id': 0,
#  'main': {'feels_like': 79.29,
#           'humidity': 61,
#           'pressure': 1009,
#           'temp': 79.29,
#           'temp_max': 80.08,
#           'temp_min': 78.42},
#  'name': 'Craig',
#  'sys': {'country': 'US',
#          'id': 6059,
#          'sunrise': 1691580451,
#          'sunset': 1691631286,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 3.44}}
# {'base': 'stations',
#  'clouds': {'all': 32},
#  'cod': 200,
#  'coord': {'lat': 41.9966, 'lon': -96.2595},
#  'dt': 1691622813,
#  'id': 0,
#  'main': {'feels_like': 79.92,
#           'grnd_level': 969,
#           'humidity': 63,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 79.92,
#           'temp_max': 80.89,
#           'temp_min': 78.98},
#  'name': 'Decatur',
#  'sys': {'country': 'US',
#          'id': 2039347,
#          'sunrise': 1691580389,
#          'sunset': 1691631284,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 195, 'gust': 5.32, 'speed': 4.12}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2756, 'lon': -96.2431},
#  'dt': 1691622532,
#  'id': 0,
#  'main': {'feels_like': 79.97,
#           'humidity': 66,
#           'pressure': 1010,
#           'temp': 79.97,
#           'temp_max': 81.59,
#           'temp_min': 76.86},
#  'name': 'Elkhorn',
#  'sys': {'country': 'US',
#          'id': 2039709,
#          'sunrise': 1691580480,
#          'sunset': 1691631185,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.4373, 'lon': -96.0324},
#  'dt': 1691622813,
#  'id': 0,
#  'main': {'feels_like': 79.63,
#           'humidity': 63,
#           'pressure': 1010,
#           'temp': 79.63,
#           'temp_max': 81.54,
#           'temp_min': 77.4},
#  'name': 'Fort Calhoun',
#  'sys': {'country': 'US',
#          'id': 3506,
#          'sunrise': 1691580409,
#          'sunset': 1691631156,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.4416, 'lon': -96.4945},
#  'dt': 1691622814,
#  'id': 0,
#  'main': {'feels_like': 79.16,
#           'humidity': 68,
#           'pressure': 1010,
#           'temp': 79.16,
#           'temp_max': 81.01,
#           'temp_min': 77.11},
#  'name': 'Fremont',
#  'sys': {'country': 'US',
#          'id': 4077,
#          'sunrise': 1691580519,
#          'sunset': 1691631267,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.4333, 'lon': -96.4981},
#  'dt': 1691622814,
#  'id': 0,
#  'main': {'feels_like': 79.12,
#           'humidity': 68,
#           'pressure': 1010,
#           'temp': 79.12,
#           'temp_max': 81,
#           'temp_min': 77.09},
#  'name': 'Fremont',
#  'sys': {'country': 'US',
#          'id': 4077,
#          'sunrise': 1691580521,
#          'sunset': 1691631267,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.1345, 'lon': -96.2458},
#  'dt': 1691622814,
#  'id': 0,
#  'main': {'feels_like': 79.72,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 79.72,
#           'temp_max': 81.82,
#           'temp_min': 76.75},
#  'name': 'Gretna',
#  'sys': {'country': 'US',
#          'id': 2002782,
#          'sunrise': 1691580499,
#          'sunset': 1691631168,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.6524, 'lon': -96.2869},
#  'dt': 1691622815,
#  'id': 0,
#  'main': {'feels_like': 79.56,
#           'humidity': 61,
#           'pressure': 1009,
#           'temp': 79.56,
#           'temp_max': 80.74,
#           'temp_min': 78.26},
#  'name': 'Herman',
#  'sys': {'country': 'US',
#          'id': 2003014,
#          'sunrise': 1691580442,
#          'sunset': 1691631245,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 3.44}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 42.3322, 'lon': -96.4656},
#  'dt': 1691622815,
#  'id': 0,
#  'main': {'feels_like': 81.86,
#           'humidity': 53,
#           'pressure': 1009,
#           'temp': 80.76,
#           'temp_max': 82.06,
#           'temp_min': 79.25},
#  'name': 'Homer',
#  'sys': {'country': 'US',
#          'id': 5945,
#          'sunrise': 1691580394,
#          'sunset': 1691631378,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 45},
#  'cod': 200,
#  'coord': {'lat': 41.6414, 'lon': -96.5232},
#  'dt': 1691622815,
#  'id': 0,
#  'main': {'feels_like': 79.23,
#           'humidity': 69,
#           'pressure': 1008,
#           'temp': 79.23,
#           'temp_max': 80.94,
#           'temp_min': 78.78},
#  'name': 'Hooper',
#  'sys': {'country': 'US',
#          'id': 2008026,
#          'sunrise': 1691580500,
#          'sunset': 1691631300,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 312, 'gust': 8.55, 'speed': 3.83}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.1748, 'lon': -96.5298},
#  'dt': 1691622815,
#  'id': 0,
#  'main': {'feels_like': 79.23,
#           'humidity': 69,
#           'pressure': 1010,
#           'temp': 79.23,
#           'temp_max': 84.38,
#           'temp_min': 77.18},
#  'name': 'Ithaca',
#  'sys': {'country': 'US',
#          'id': 3248,
#          'sunrise': 1691580562,
#          'sunset': 1691631241,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.4526, 'lon': -96.1903},
#  'dt': 1691622816,
#  'id': 0,
#  'main': {'feels_like': 82.36,
#           'humidity': 64,
#           'pressure': 1010,
#           'temp': 80.08,
#           'temp_max': 81.91,
#           'temp_min': 77.31},
#  'name': 'Kennard',
#  'sys': {'country': 'US',
#          'id': 3506,
#          'sunrise': 1691580445,
#          'sunset': 1691631196,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 71},
#  'cod': 200,
#  'coord': {'lat': 41.4129, 'lon': -96.9399},
#  'dt': 1691622816,
#  'id': 0,
#  'main': {'feels_like': 81.14,
#           'grnd_level': 960,
#           'humidity': 49,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.49,
#           'temp_max': 83.5,
#           'temp_min': 76.62},
#  'name': 'Linwood',
#  'sys': {'country': 'US',
#          'id': 5199,
#          'sunrise': 1691580630,
#          'sunset': 1691631370,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 7, 'gust': 8.68, 'speed': 6.93}}
# {'base': 'stations',
#  'clouds': {'all': 91},
#  'cod': 200,
#  'coord': {'lat': 40.9967, 'lon': -96.1948},
#  'dt': 1691622816,
#  'id': 0,
#  'main': {'feels_like': 83.28,
#           'humidity': 68,
#           'pressure': 1005,
#           'temp': 80.37,
#           'temp_max': 83.8,
#           'temp_min': 77.34},
#  'name': 'Louisville',
#  'sys': {'country': 'US',
#          'id': 2001701,
#          'sunrise': 1691580505,
#          'sunset': 1691631138,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 18, 'gust': 10.36, 'speed': 10}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.9442, 'lon': -96.4661},
#  'dt': 1691622817,
#  'id': 0,
#  'main': {'feels_like': 79.23,
#           'grnd_level': 961,
#           'humidity': 57,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 79.23,
#           'temp_max': 80.08,
#           'temp_min': 78.69},
#  'name': 'Lyons',
#  'sys': {'country': 'US',
#          'id': 2039347,
#          'sunrise': 1691580446,
#          'sunset': 1691631326,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 174, 'gust': 4.92, 'speed': 1.3}}
# {'base': 'stations',
#  'clouds': {'all': 42},
#  'cod': 200,
#  'coord': {'lat': 42.1177, 'lon': -96.3589},
#  'dt': 1691622817,
#  'id': 0,
#  'main': {'feels_like': 79.7,
#           'grnd_level': 966,
#           'humidity': 53,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 79.7,
#           'temp_max': 80.31,
#           'temp_min': 78.67},
#  'name': 'Macy',
#  'sys': {'country': 'US',
#          'id': 2039347,
#          'sunrise': 1691580397,
#          'sunset': 1691631324,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 359, 'gust': 6.67, 'speed': 0.78}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2984, 'lon': -96.7327},
#  'dt': 1691622817,
#  'id': 0,
#  'main': {'feels_like': 78.03,
#           'humidity': 69,
#           'pressure': 1010,
#           'temp': 77.34,
#           'temp_max': 83.37,
#           'temp_min': 76.32},
#  'name': 'Malmo',
#  'sys': {'country': 'US',
#          'id': 3248,
#          'sunrise': 1691580595,
#          'sunset': 1691631306,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2393, 'lon': -96.4961},
#  'dt': 1691622818,
#  'id': 0,
#  'main': {'feels_like': 79.07,
#           'humidity': 68,
#           'pressure': 1010,
#           'temp': 79.07,
#           'temp_max': 83.37,
#           'temp_min': 77.02},
#  'name': 'Mead',
#  'sys': {'country': 'US',
#          'id': 3248,
#          'sunrise': 1691580546,
#          'sunset': 1691631241,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': 41.0946, 'lon': -96.4306},
#  'dt': 1691622818,
#  'id': 0,
#  'main': {'feels_like': 82.78,
#           'grnd_level': 967,
#           'humidity': 66,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.2,
#           'temp_max': 84.56,
#           'temp_min': 77.25},
#  'name': 'Memphis',
#  'sys': {'country': 'US',
#          'id': 2039995,
#          'sunrise': 1691580549,
#          'sunset': 1691631207,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'gust': 10.27, 'speed': 8.39}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.5491, 'lon': -96.4441},
#  'dt': 1691622818,
#  'id': 0,
#  'main': {'feels_like': 79.47,
#           'humidity': 69,
#           'pressure': 1010,
#           'temp': 79.47,
#           'temp_max': 81.01,
#           'temp_min': 78.28},
#  'name': 'Nickerson',
#  'sys': {'country': 'US',
#          'id': 2008026,
#          'sunrise': 1691580493,
#          'sunset': 1691631269,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 43},
#  'cod': 200,
#  'coord': {'lat': 41.8384, 'lon': -96.4671},
#  'dt': 1691622711,
#  'id': 0,
#  'main': {'feels_like': 79.21,
#           'grnd_level': 962,
#           'humidity': 58,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 79.21,
#           'temp_max': 80.13,
#           'temp_min': 78.48},
#  'name': 'Oakland',
#  'sys': {'country': 'US',
#          'id': 6059,
#          'sunrise': 1691580460,
#          'sunset': 1691631313,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 269, 'gust': 6.26, 'speed': 1.88}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.1523, 'lon': -96.0371},
#  'dt': 1691622819,
#  'id': 0,
#  'main': {'feels_like': 83.32,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.67,
#           'temp_max': 82.38,
#           'temp_min': 77.65},
#  'name': 'Papillion',
#  'sys': {'country': 'US',
#          'id': 2085815,
#          'sunrise': 1691580447,
#          'sunset': 1691631120,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 42.1177, 'lon': -96.7189},
#  'dt': 1691622819,
#  'id': 0,
#  'main': {'feels_like': 81.9,
#           'grnd_level': 961,
#           'humidity': 52,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.92,
#           'temp_max': 81.23,
#           'temp_min': 79.75},
#  'name': 'Pender',
#  'sys': {'country': 'US',
#          'id': 4683,
#          'sunrise': 1691580484,
#          'sunset': 1691631410,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 339, 'gust': 8.03, 'speed': 5.23}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 40.9992, 'lon': -95.9139},
#  'dt': 1691622819,
#  'id': 0,
#  'main': {'feels_like': 79.97,
#           'humidity': 66,
#           'pressure': 1009,
#           'temp': 79.97,
#           'temp_max': 81.88,
#           'temp_min': 77.04},
#  'name': 'Plattsmouth',
#  'sys': {'country': 'US',
#          'id': 2039125,
#          'sunrise': 1691580437,
#          'sunset': 1691631071,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 270, 'speed': 4.61}}
# {'base': 'stations',
#  'clouds': {'all': 77},
#  'cod': 200,
#  'coord': {'lat': 41.3036, 'lon': -96.8301},
#  'dt': 1691622820,
#  'id': 0,
#  'main': {'feels_like': 76.91,
#           'grnd_level': 956,
#           'humidity': 48,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 77.23,
#           'temp_max': 83.01,
#           'temp_min': 76.21},
#  'name': 'Prague',
#  'sys': {'country': 'US',
#          'id': 3248,
#          'sunrise': 1691580618,
#          'sunset': 1691631330,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 17, 'gust': 8.5, 'speed': 6.73}}
# {'base': 'stations',
#  'clouds': {'all': 34},
#  'cod': 200,
#  'coord': {'lat': 42.0574, 'lon': -96.4929},
#  'dt': 1691622820,
#  'id': 0,
#  'main': {'feels_like': 79.03,
#           'grnd_level': 957,
#           'humidity': 53,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 79.03,
#           'temp_max': 80.85,
#           'temp_min': 77.76},
#  'name': 'Rosalie',
#  'sys': {'country': 'US',
#          'id': 2039347,
#          'sunrise': 1691580437,
#          'sunset': 1691631348,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 13, 'gust': 5.48, 'speed': 0.76}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.0927, 'lon': -96.0905},
#  'dt': 1691622820,
#  'id': 0,
#  'main': {'feels_like': 82.89,
#           'humidity': 66,
#           'pressure': 1009,
#           'temp': 80.28,
#           'temp_max': 82.02,
#           'temp_min': 77.29},
#  'name': 'St Columbans',
#  'sys': {'country': 'US',
#          'id': 2085815,
#          'sunrise': 1691580467,
#          'sunset': 1691631125,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 39},
#  'cod': 200,
#  'coord': {'lat': 41.663, 'lon': -96.6441},
#  'dt': 1691622821,
#  'id': 0,
#  'main': {'feels_like': 78.93,
#           'humidity': 69,
#           'pressure': 1008,
#           'temp': 78.93,
#           'temp_max': 80.31,
#           'temp_min': 76.93},
#  'name': 'Scribner',
#  'sys': {'country': 'US',
#          'id': 2008026,
#          'sunrise': 1691580526,
#          'sunset': 1691631332,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 306, 'gust': 8.86, 'speed': 4.47}}
# {'base': 'stations',
#  'clouds': {'all': 90},
#  'cod': 200,
#  'coord': {'lat': 41.0067, 'lon': -96.2462},
#  'dt': 1691622821,
#  'id': 0,
#  'main': {'feels_like': 83.64,
#           'humidity': 68,
#           'pressure': 1005,
#           'temp': 80.6,
#           'temp_max': 84.7,
#           'temp_min': 77.54},
#  'name': 'South Bend',
#  'sys': {'country': 'US',
#          'id': 2001701,
#          'sunrise': 1691580516,
#          'sunset': 1691631151,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 21, 'gust': 10.47, 'speed': 10.11}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.0765, 'lon': -96.1438},
#  'dt': 1691622821,
#  'id': 0,
#  'main': {'feels_like': 82.71,
#           'humidity': 65,
#           'pressure': 1008,
#           'temp': 80.24,
#           'temp_max': 82.02,
#           'temp_min': 77.29},
#  'name': 'Springfield',
#  'sys': {'country': 'US',
#          'id': 2001701,
#          'sunrise': 1691580482,
#          'sunset': 1691631136,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.7819, 'lon': -96.2281},
#  'dt': 1691622822,
#  'id': 0,
#  'main': {'feels_like': 82.2,
#           'humidity': 61,
#           'pressure': 1009,
#           'temp': 80.22,
#           'temp_max': 80.76,
#           'temp_min': 78.85},
#  'name': 'Tekamah',
#  'sys': {'country': 'US',
#          'id': 6059,
#          'sunrise': 1691580410,
#          'sunset': 1691631248,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 320, 'speed': 3.44}}
# {'base': 'stations',
#  'clouds': {'all': 39},
#  'cod': 200,
#  'coord': {'lat': 42.1882, 'lon': -96.6904},
#  'dt': 1691622822,
#  'id': 0,
#  'main': {'feels_like': 81,
#           'grnd_level': 959,
#           'humidity': 47,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.56,
#           'temp_max': 81.05,
#           'temp_min': 78.24},
#  'name': 'Thurston',
#  'sys': {'country': 'US',
#          'id': 4683,
#          'sunrise': 1691580467,
#          'sunset': 1691631413,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 349, 'gust': 8.99, 'speed': 7.96}}
# {'base': 'stations',
#  'clouds': {'all': 45},
#  'cod': 200,
#  'coord': {'lat': 41.7369, 'lon': -96.5037},
#  'dt': 1691622822,
#  'id': 0,
#  'main': {'feels_like': 79.16,
#           'grnd_level': 963,
#           'humidity': 69,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 79.16,
#           'temp_max': 80.26,
#           'temp_min': 78.62},
#  'name': 'Uehling',
#  'sys': {'country': 'US',
#          'id': 2008026,
#          'sunrise': 1691580483,
#          'sunset': 1691631308,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 286, 'gust': 7.74, 'speed': 3.98}}
# {'base': 'stations',
#  'clouds': {'all': 64},
#  'cod': 200,
#  'coord': {'lat': 41.3186, 'lon': -96.3463},
#  'dt': 1691622822,
#  'id': 0,
#  'main': {'feels_like': 79.97,
#           'humidity': 68,
#           'pressure': 1008,
#           'temp': 79.97,
#           'temp_max': 81.9,
#           'temp_min': 77.29},
#  'name': 'Valley',
#  'sys': {'country': 'US',
#          'id': 233802,
#          'sunrise': 1691580499,
#          'sunset': 1691631215,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 315, 'gust': 4, 'speed': 1.01}}
# {'base': 'stations',
#  'clouds': {'all': 86},
#  'cod': 200,
#  'coord': {'lat': 41.0843, 'lon': -96.8091},
#  'dt': 1691622823,
#  'id': 0,
#  'main': {'feels_like': 81.66,
#           'grnd_level': 956,
#           'humidity': 43,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 81.82,
#           'temp_max': 83.41,
#           'temp_min': 77.95},
#  'name': 'Valparaiso',
#  'sys': {'country': 'US',
#          'id': 2003087,
#          'sunrise': 1691580641,
#          'sunset': 1691631296,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 21, 'gust': 9.71, 'speed': 5.86}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2117, 'lon': -96.6219},
#  'dt': 1691622823,
#  'id': 0,
#  'main': {'feels_like': 79.05,
#           'humidity': 69,
#           'pressure': 1010,
#           'temp': 78.28,
#           'temp_max': 82.02,
#           'temp_min': 77.05},
#  'name': 'Wahoo',
#  'sys': {'country': 'US',
#          'id': 3248,
#          'sunrise': 1691580580,
#          'sunset': 1691631268,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 28},
#  'cod': 200,
#  'coord': {'lat': 42.1485, 'lon': -96.4803},
#  'dt': 1691622823,
#  'id': 0,
#  'main': {'feels_like': 80.69,
#           'grnd_level': 964,
#           'humidity': 47,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.2,
#           'temp_max': 81.52,
#           'temp_min': 78.42},
#  'name': 'Walthill',
#  'sys': {'country': 'US',
#          'id': 5945,
#          'sunrise': 1691580422,
#          'sunset': 1691631357,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 338, 'gust': 7.67, 'speed': 4.68}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.3975, 'lon': -96.2081},
#  'dt': 1691622824,
#  'id': 0,
#  'main': {'feels_like': 82.58,
#           'humidity': 65,
#           'pressure': 1010,
#           'temp': 80.15,
#           'temp_max': 81.93,
#           'temp_min': 77.32},
#  'name': 'Washington',
#  'sys': {'country': 'US',
#          'id': 3506,
#          'sunrise': 1691580456,
#          'sunset': 1691631193,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2702, 'lon': -96.3063},
#  'dt': 1691622824,
#  'id': 0,
#  'main': {'feels_like': 82.67,
#           'humidity': 66,
#           'pressure': 1009,
#           'temp': 80.13,
#           'temp_max': 81.97,
#           'temp_min': 77.23},
#  'name': 'Waterloo',
#  'sys': {'country': 'US',
#          'id': 233802,
#          'sunrise': 1691580496,
#          'sunset': 1691631200,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 300, 'speed': 6.91}}
# {'base': 'stations',
#  'clouds': {'all': 83},
#  'cod': 200,
#  'coord': {'lat': 41.1811, 'lon': -96.7691},
#  'dt': 1691622824,
#  'id': 0,
#  'main': {'feels_like': 81.28,
#           'grnd_level': 961,
#           'humidity': 45,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 81.14,
#           'temp_max': 83.91,
#           'temp_min': 78.46},
#  'name': 'Weston',
#  'sys': {'country': 'US',
#          'id': 2003087,
#          'sunrise': 1691580619,
#          'sunset': 1691631299,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 24, 'gust': 8.97, 'speed': 6.73}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 42.2339, 'lon': -96.4685},
#  'dt': 1691622825,
#  'id': 0,
#  'main': {'feels_like': 82.26,
#           'humidity': 61,
#           'pressure': 1009,
#           'temp': 80.28,
#           'temp_max': 81.5,
#           'temp_min': 78.4},
#  'name': 'Winnebago',
#  'sys': {'country': 'US',
#          'id': 5945,
#          'sunrise': 1691580408,
#          'sunset': 1691631366,
#          'type': 1},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 270, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.6102, 'lon': -96.5033},
#  'dt': 1691622825,
#  'id': 0,
#  'main': {'feels_like': 79.2,
#           'humidity': 69,
#           'pressure': 1009,
#           'temp': 79.2,
#           'temp_max': 80.94,
#           'temp_min': 78.78},
#  'name': 'Winslow',
#  'sys': {'country': 'US',
#          'id': 2008026,
#          'sunrise': 1691580499,
#          'sunset': 1691631291,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 67},
#  'cod': 200,
#  'coord': {'lat': 41.234, 'lon': -96.3932},
#  'dt': 1691622825,
#  'id': 0,
#  'main': {'feels_like': 82.98,
#           'grnd_level': 966,
#           'humidity': 68,
#           'pressure': 1005,
#           'sea_level': 1005,
#           'temp': 80.17,
#           'temp_max': 81.88,
#           'temp_min': 78.42},
#  'name': 'Yutan',
#  'sys': {'country': 'US',
#          'id': 233802,
#          'sunrise': 1691580522,
#          'sunset': 1691631216,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 30, 'gust': 9.98, 'speed': 8.05}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2586, 'lon': -95.9378},
#  'dt': 1691622628,
#  'id': 0,
#  'main': {'feels_like': 82.96,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.51,
#           'temp_max': 82.2,
#           'temp_min': 78.06},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580409,
#          'sunset': 1691631110,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.259, 'lon': -95.9409},
#  'dt': 1691622826,
#  'id': 0,
#  'main': {'feels_like': 82.53,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.2,
#           'temp_max': 82.04,
#           'temp_min': 77.9},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580410,
#          'sunset': 1691631111,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2586, 'lon': -95.9378},
#  'dt': 1691622680,
#  'id': 0,
#  'main': {'feels_like': 82.96,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.51,
#           'temp_max': 82.2,
#           'temp_min': 78.06},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580409,
#          'sunset': 1691631110,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2919, 'lon': -95.9999},
#  'dt': 1691622826,
#  'id': 0,
#  'main': {'feels_like': 79.88,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 79.88,
#           'temp_max': 81.72,
#           'temp_min': 76.98},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2079634,
#          'sunrise': 1691580420,
#          'sunset': 1691631129,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2435, 'lon': -95.9629},
#  'dt': 1691622827,
#  'id': 0,
#  'main': {'feels_like': 79.84,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 79.84,
#           'temp_max': 81.64,
#           'temp_min': 77.5},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2079634,
#          'sunrise': 1691580417,
#          'sunset': 1691631114,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2403, 'lon': -95.998},
#  'dt': 1691622827,
#  'id': 0,
#  'main': {'feels_like': 82.76,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.28,
#           'temp_max': 82.09,
#           'temp_min': 77.34},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2079634,
#          'sunrise': 1691580426,
#          'sunset': 1691631122,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2068, 'lon': -95.9559},
#  'dt': 1691622552,
#  'id': 0,
#  'main': {'feels_like': 82.98,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.44,
#           'temp_max': 82.02,
#           'temp_min': 77.88},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 38540,
#          'sunrise': 1691580420,
#          'sunset': 1691631107,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2382, 'lon': -95.9336},
#  'dt': 1691622689,
#  'id': 0,
#  'main': {'feels_like': 82.44,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.13,
#           'temp_max': 81.82,
#           'temp_min': 77.68},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580411,
#          'sunset': 1691631106,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2586, 'lon': -95.9378},
#  'dt': 1691622790,
#  'id': 0,
#  'main': {'feels_like': 82.83,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.42,
#           'temp_max': 82.2,
#           'temp_min': 78.06},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580409,
#          'sunset': 1691631110,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2933, 'lon': -95.9361},
#  'dt': 1691622828,
#  'id': 0,
#  'main': {'feels_like': 82.72,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.35,
#           'temp_max': 82.26,
#           'temp_min': 77.52},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580404,
#          'sunset': 1691631114,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2962, 'lon': -95.965},
#  'dt': 1691622828,
#  'id': 0,
#  'main': {'feels_like': 82.67,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.22,
#           'temp_max': 82.09,
#           'temp_min': 77.34},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580411,
#          'sunset': 1691631121,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.3296, 'lon': -95.9597},
#  'dt': 1691622829,
#  'id': 0,
#  'main': {'feels_like': 82.85,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.35,
#           'temp_max': 82.26,
#           'temp_min': 77.52},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580405,
#          'sunset': 1691631124,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 41.2563, 'lon': -95.9404},
#  'dt': 1691622829,
#  'id': 0,
#  'main': {'feels_like': 82.53,
#           'humidity': 64,
#           'pressure': 1009,
#           'temp': 80.2,
#           'temp_max': 82.04,
#           'temp_min': 77.9},
#  'name': 'Offutt Afb',
#  'sys': {'country': 'US',
#          'id': 2003015,
#          'sunrise': 1691580410,
#          'sunset': 1691631110,
#          'type': 2},
#  'timezone': -18000,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 10, 'speed': 9.22}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.2656, 'lon': -96.0493},
#  'dt': 1691622829,
#  'id': 0,
#  'main': {'feels_like': 82.53,
#           'humidity': 65,
#           'pressure': 1009,
#           'temp': 80.11,
#           'temp_max': 81.9,
#           'temp_min': 77.16},
#  'name': 'Omaha',
#  'sys': {'country': 'US',
#          'id': 2044496,
#          'sunrise': 1691580435,
#          'sunset': 1691631137,
#          'type': 2},
#  'timezone': -18000,
# ...
#           'grnd_level': 885,
#           'humidity': 26,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 80.42,
#           'temp_max': 81.9,
#           'temp_min': 79.45},
#  'name': 'Crawford',
#  'sys': {'country': 'US',
#          'id': 3593,
#          'sunrise': 1691582014,
#          'sunset': 1691633089,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 344, 'gust': 7.94, 'speed': 2.77}}
# {'base': 'stations',
#  'clouds': {'all': 44},
#  'cod': 200,
#  'coord': {'lat': 42.0586, 'lon': -102.2807},
#  'dt': 1691623035,
#  'id': 0,
#  'main': {'feels_like': 79.79,
#           'grnd_level': 881,
#           'humidity': 33,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 80.62,
#           'temp_max': 80.62,
#           'temp_min': 80.62},
#  'name': 'Ellsworth',
#  'sys': {'country': 'US',
#          'id': 3249,
#          'sunrise': 1691581827,
#          'sunset': 1691632736,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 342, 'gust': 7.47, 'speed': 5.12}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.822, 'lon': -103.6629},
#  'dt': 1691623035,
#  'id': 0,
#  'main': {'feels_like': 82.24,
#           'humidity': 35,
#           'pressure': 1009,
#           'temp': 83.61,
#           'temp_max': 85.17,
#           'temp_min': 81.45},
#  'name': 'Gering',
#  'sys': {'country': 'US',
#          'id': 2039237,
#          'sunrise': 1691582191,
#          'sunset': 1691633036,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 279, 'gust': 7, 'speed': 3}}
# {'base': 'stations',
#  'clouds': {'all': 40},
#  'cod': 200,
#  'coord': {'lat': 42.8068, 'lon': -102.2049},
#  'dt': 1691623035,
#  'id': 0,
#  'main': {'feels_like': 78.76,
#           'humidity': 44,
#           'pressure': 1013,
#           'temp': 78.76,
#           'temp_max': 79.74,
#           'temp_min': 78.76},
#  'name': 'Gordon',
#  'sys': {'country': 'US',
#          'id': 4265,
#          'sunrise': 1691581708,
#          'sunset': 1691632819,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'scattered clouds',
#               'icon': '03d',
#               'id': 802,
#               'main': 'Clouds'}],
#  'wind': {'deg': 260, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.5531, 'lon': -103.7111},
#  'dt': 1691623036,
#  'id': 0,
#  'main': {'feels_like': 80.06,
#           'grnd_level': 861,
#           'humidity': 38,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 80.44,
#           'temp_max': 82.74,
#           'temp_min': 78.12},
#  'name': 'Harrisburg',
#  'sys': {'country': 'US',
#          'id': 2011467,
#          'sunrise': 1691582238,
#          'sunset': 1691633012,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 344, 'gust': 10.27, 'speed': 6.78}}
# {'base': 'stations',
#  'clouds': {'all': 3},
#  'cod': 200,
#  'coord': {'lat': 42.6872, 'lon': -103.8827},
#  'dt': 1691623036,
#  'id': 0,
#  'main': {'feels_like': 77.43,
#           'humidity': 41,
#           'pressure': 1014,
#           'temp': 78.01,
#           'temp_max': 78.01,
#           'temp_min': 77.18},
#  'name': 'Harrison',
#  'sys': {'country': 'US',
#          'id': 2005961,
#          'sunrise': 1691582127,
#          'sunset': 1691633205,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 53, 'gust': 5.99, 'speed': 1.99}}
# {'base': 'stations',
#  'clouds': {'all': 11},
#  'cod': 200,
#  'coord': {'lat': 42.6401, 'lon': -102.6756},
#  'dt': 1691622808,
#  'id': 0,
#  'main': {'feels_like': 79.57,
#           'grnd_level': 885,
#           'humidity': 32,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 79.57,
#           'temp_max': 80.69,
#           'temp_min': 77.99},
#  'name': 'Hay Springs',
#  'sys': {'country': 'US',
#          'id': 2007979,
#          'sunrise': 1691581844,
#          'sunset': 1691632909,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 317, 'gust': 6.35, 'speed': 5.28}}
# {'base': 'stations',
#  'clouds': {'all': 2},
#  'cod': 200,
#  'coord': {'lat': 42.3312, 'lon': -103.0644},
#  'dt': 1691623037,
#  'id': 0,
#  'main': {'feels_like': 79.23,
#           'grnd_level': 871,
#           'humidity': 30,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 79.23,
#           'temp_max': 79.45,
#           'temp_min': 79.23},
#  'name': 'Hemingford',
#  'sys': {'country': 'US',
#          'id': 2020636,
#          'sunrise': 1691581979,
#          'sunset': 1691632960,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 339, 'gust': 8.01, 'speed': 5.03}}
# {'base': 'stations',
#  'clouds': {'all': 81},
#  'cod': 200,
#  'coord': {'lat': 42.007, 'lon': -101.7483},
#  'dt': 1691623037,
#  'id': 0,
#  'main': {'feels_like': 75.67,
#           'grnd_level': 886,
#           'humidity': 41,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 76.41,
#           'temp_max': 76.41,
#           'temp_min': 76.41},
#  'name': 'Hyannis',
#  'sys': {'country': 'US', 'sunrise': 1691581706, 'sunset': 1691632601},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 353, 'gust': 5.37, 'speed': 2.42}}
# {'base': 'stations',
#  'clouds': {'all': 18},
#  'cod': 200,
#  'coord': {'lat': 42.0496, 'lon': -102.4437},
#  'dt': 1691623037,
#  'id': 0,
#  'main': {'feels_like': 79.77,
#           'grnd_level': 882,
#           'humidity': 32,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 80.71,
#           'temp_max': 80.71,
#           'temp_min': 80.49},
#  'name': 'Lakeside',
#  'sys': {'country': 'US',
#          'id': 3249,
#          'sunrise': 1691581868,
#          'sunset': 1691632774,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 344, 'gust': 7.61, 'speed': 5.57}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.8918, 'lon': -104.0066},
#  'dt': 1691623038,
#  'id': 0,
#  'main': {'feels_like': 81.16,
#           'grnd_level': 877,
#           'humidity': 38,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 81.91,
#           'temp_max': 84.65,
#           'temp_min': 80.92},
#  'name': 'Lyman',
#  'sys': {'country': 'US',
#          'id': 2043916,
#          'sunrise': 1691582264,
#          'sunset': 1691633128,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 350, 'gust': 8.14, 'speed': 3.38}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.7469, 'lon': -103.4164},
#  'dt': 1691623038,
#  'id': 0,
#  'main': {'feels_like': 81.77,
#           'grnd_level': 885,
#           'humidity': 27,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 84.06,
#           'temp_max': 85.64,
#           'temp_min': 81.93},
#  'name': 'Mcgrew',
#  'sys': {'country': 'US',
#          'id': 3415,
#          'sunrise': 1691582141,
#          'sunset': 1691632967,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 337, 'gust': 8.81, 'speed': 5.73}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 42.5244, 'lon': -103.2564},
#  'dt': 1691623038,
#  'id': 0,
#  'main': {'feels_like': 77.02,
#           'grnd_level': 870,
#           'humidity': 28,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 78.19,
#           'temp_max': 79.11,
#           'temp_min': 77.65},
#  'name': 'Marsland',
#  'sys': {'country': 'US',
#          'id': 3593,
#          'sunrise': 1691581999,
#          'sunset': 1691633032,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 347, 'gust': 8.19, 'speed': 3.2}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.7816, 'lon': -103.5177},
#  'dt': 1691623039,
#  'id': 0,
#  'main': {'feels_like': 82.47,
#           'humidity': 34,
#           'pressure': 1014,
#           'temp': 84.02,
#           'temp_max': 85.51,
#           'temp_min': 81.79},
#  'name': 'Melbeta',
#  'sys': {'country': 'US',
#          'id': 3415,
#          'sunrise': 1691582161,
#          'sunset': 1691632996,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.8493, 'lon': -103.489},
#  'dt': 1691623039,
#  'id': 0,
#  'main': {'feels_like': 81.81,
#           'humidity': 33,
#           'pressure': 1014,
#           'temp': 83.37,
#           'temp_max': 85.1,
#           'temp_min': 81.37},
#  'name': 'Minatare',
#  'sys': {'country': 'US',
#          'id': 3415,
#          'sunrise': 1691582145,
#          'sunset': 1691632998,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.9459, 'lon': -103.796},
#  'dt': 1691623039,
#  'id': 0,
#  'main': {'feels_like': 80.92,
#           'humidity': 35,
#           'pressure': 1014,
#           'temp': 81.99,
#           'temp_max': 84.85,
#           'temp_min': 81.12},
#  'name': 'Mitchell',
#  'sys': {'country': 'US',
#          'id': 2043916,
#          'sunrise': 1691582206,
#          'sunset': 1691633084,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 248, 'gust': 4, 'speed': 1.99}}
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 41.9681, 'lon': -103.9182},
#  'dt': 1691623040,
#  'id': 0,
#  'main': {'feels_like': 81.14,
#           'grnd_level': 879,
#           'humidity': 38,
#           'pressure': 1007,
#           'sea_level': 1007,
#           'temp': 81.9,
#           'temp_max': 84.9,
#           'temp_min': 81.19},
#  'name': 'Morrill',
#  'sys': {'country': 'US',
#          'id': 2043916,
#          'sunrise': 1691582233,
#          'sunset': 1691633116,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 324, 'gust': 8.01, 'speed': 3.2}}
# {'base': 'stations',
#  'clouds': {'all': 22},
#  'cod': 200,
#  'coord': {'lat': 42.7379, 'lon': -102.4657},
#  'dt': 1691623040,
#  'id': 0,
#  'main': {'feels_like': 77.5,
#           'grnd_level': 886,
#           'humidity': 33,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 78.4,
#           'temp_max': 79.57,
#           'temp_min': 78.1},
#  'name': 'Rushville',
#  'sys': {'country': 'US',
#          'id': 4265,
#          'sunrise': 1691581780,
#          'sunset': 1691632872,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'few clouds',
#               'icon': '02d',
#               'id': 801,
#               'main': 'Clouds'}],
#  'wind': {'deg': 309, 'gust': 6.33, 'speed': 5.68}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.872, 'lon': -103.6619},
#  'dt': 1691623040,
#  'id': 0,
#  'main': {'feels_like': 82.13,
#           'humidity': 35,
#           'pressure': 1010,
#           'temp': 83.48,
#           'temp_max': 85.28,
#           'temp_min': 81.55},
#  'name': 'Scottsbluff',
#  'sys': {'country': 'US',
#          'id': 3415,
#          'sunrise': 1691582184,
#          'sunset': 1691633042,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 279, 'gust': 7, 'speed': 3}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 41.8666, 'lon': -103.6672},
#  'dt': 1691622907,
#  'id': 0,
#  'main': {'feels_like': 82.4,
#           'humidity': 34,
#           'pressure': 1008,
#           'temp': 83.93,
#           'temp_max': 85.28,
#           'temp_min': 81.55},
#  'name': 'Scottsbluff',
#  'sys': {'country': 'US',
#          'id': 2080409,
#          'sunrise': 1691582186,
#          'sunset': 1691633043,
#          'type': 2},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 0, 'speed': 0}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 42.9969, 'lon': -102.5546},
#  'dt': 1691623041,
#  'id': 0,
#  'main': {'feels_like': 80.47,
#           'humidity': 41,
#           'pressure': 1013,
#           'temp': 80.64,
#           'temp_max': 82.38,
#           'temp_min': 79.68},
#  'name': 'Whiteclay',
#  'sys': {'country': 'US',
#          'id': 4501,
#          'sunrise': 1691581766,
#          'sunset': 1691632929,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 260, 'speed': 5.75}}
# {'base': 'stations',
#  'clouds': {'all': 73},
#  'cod': 200,
#  'coord': {'lat': 41.9584, 'lon': -101.5216},
#  'dt': 1691623041,
#  'id': 0,
#  'main': {'feels_like': 75.18,
#           'grnd_level': 888,
#           'humidity': 46,
#           'pressure': 1008,
#           'sea_level': 1008,
#           'temp': 75.74,
#           'temp_max': 75.74,
#           'temp_min': 75.74},
#  'name': 'Whitman',
#  'sys': {'country': 'US', 'sunrise': 1691581658, 'sunset': 1691632541},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'broken clouds',
#               'icon': '04d',
#               'id': 803,
#               'main': 'Clouds'}],
#  'wind': {'deg': 283, 'gust': 6.78, 'speed': 4.76}}
# {'base': 'stations',
#  'clouds': {'all': 0},
#  'cod': 200,
#  'coord': {'lat': 42.7559, 'lon': -103.2396},
#  'dt': 1691623041,
#  'id': 0,
#  'main': {'feels_like': 81.07,
#           'humidity': 39,
#           'pressure': 1013,
#           'temp': 81.66,
#           'temp_max': 81.66,
#           'temp_min': 80.44},
#  'name': 'Whitney',
#  'sys': {'country': 'US',
#          'id': 3593,
#          'sunrise': 1691581964,
#          'sunset': 1691633060,
#          'type': 1},
#  'timezone': -21600,
#  'visibility': 10000,
#  'weather': [{'description': 'clear sky',
#               'icon': '01d',
#               'id': 800,
#               'main': 'Clear'}],
#  'wind': {'deg': 220, 'speed': 3.44}}

# %%
# define extract_details_and_print function
def extract_details_and_print(raw_json_data):

    # extracting location variable from data
    location = raw_json_data["name"]

    # store the value of "main" key in variable y
    y = raw_json_data["main"]

    # store the value of "temp" in current_temperature
    current_temperature = y["temp"]

    # store the value of "pressure" in current_pressure
    current_pressure = y["pressure"]

    # store the value of "humidity" in current_humidiy
    current_humidiy = y["humidity"]

    # store the value of "weather" key in variable z
    z = raw_json_data["weather"]

    # store the value corresponding to the "description" key at the 0th index of z as weather_description
    weather_description = z[0]["description"]

    #extracting wind speed from data
    wind_speed = raw_json_data["wind"]["speed"]

    #extracting date, sunrise & sunset times
    date = raw_json_data["dt"]
    
    sunrise = raw_json_data["sys"]["sunrise"]
    
    sunset = raw_json_data["sys"]["sunset"] 
    
     # converting timestamp to human readable format and print
    
    Date_time = datetime.datetime.fromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
    
    sunrise_time = datetime.datetime.fromtimestamp(sunrise).strftime('%H:%M')
    
    sunset_time = datetime.datetime.fromtimestamp(sunset).strftime('%H:%M')
    
    print(" Date & Time:", '\33[32m ' + Date_time +'\033[0m')    
                                                                                                                
    print(" Sunrise: {} \t \t Sunset : {}".format('\33[34m'+ sunrise_time+'\033[0m', '\33[34m'+ sunset_time +'\033[0m'))                                                                                       
    
    # print the following values
    print(  " Location : " + '\33[34m' + str(location) + '\033[0m'
            "\n Temperature (in Fahrenheit) : " +
            '\33[34m' + str(current_temperature) + '\033[0m' +
            "\n Atmospheric pressure (in hPa) : " +
            '\33[34m' + str(current_pressure) + '\033[0m' +
            "\n Humidity (in percentage) : " +
            '\33[34m'+ str(current_humidiy) + '\033[0m' +
            "\n Weather description : " +
            '\33[34m'+ str(weather_description)+ '\033[0m' +
            "\n Wind speed (in mi/hr) :" +
            '\33[34m'+ str(wind_speed)+ '\033[0m' +
            '\33[34m' + "\n****************************************" + '\033[0m')

# %%
# print weather data in readable format
print('\33[34m'+"***************************************"+
            "\n \t WEATHER INFORMATION" +
            "\n***************************************" + '\033[0m')

# print weather information for first 5 zipcodes
for wd in weather_data1[0:3]:    
    extract_details_and_print(wd)
# Out:
# ***************************************
#  	 WEATHER INFORMATION
# ***************************************
#  Date & Time:  2023-08-09 19:13:29
#  Sunrise: 07:30 	 	 Sunset : 21:36
#  Location : Abie
#  Temperature (in Fahrenheit) : 80.35
#  Atmospheric pressure (in hPa) : 1005
#  Humidity (in percentage) : 49
#  Weather description : broken clouds
#  Wind speed (in mi/hr) :6.58
# ****************************************
#  Date & Time:  2023-08-09 19:13:29
#  Sunrise: 07:27 	 	 Sunset : 21:33
#  Location : Arlington
#  Temperature (in Fahrenheit) : 79.43
#  Atmospheric pressure (in hPa) : 1010
#  Humidity (in percentage) : 65
#  Weather description : clear sky
#  Wind speed (in mi/hr) :6.91
# ****************************************
#  Date & Time:  2023-08-09 19:13:29
#  Sunrise: 07:29 	 	 Sunset : 21:33
#  Location : Ashland
#  Temperature (in Fahrenheit) : 80.53
#  Atmospheric pressure (in hPa) : 1005
#  Humidity (in percentage) : 66
#  Weather description : broken clouds
#  Wind speed (in mi/hr) :8.68
# ****************************************
